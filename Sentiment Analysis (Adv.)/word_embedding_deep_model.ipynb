# %%
import pandas as pd
import re
from tensorflow import keras
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Flatten, LSTM, GlobalMaxPooling1D, Bidirectional
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from gensim.models import Word2Vec
import numpy as np

# %% [markdown]
# #### Loading the dataset

# %%
df = pd.read_csv('./cleaned_data.csv')

df.head()
# Out:
#    Sentiment                                             Tweets  \
# 0          0             Wants to go home... bored of work now
# 1          0  @jeffLmsu good call on holding for take 3........
# 2          1    just watched the new moon trailer aa i love it
# 3          0                 Should I go check what it iss????
# 4          1  the mammaaaaa &amp; sister.  http://twitpic.co...
#
#                                       Cleaned_Tweets  Word_Count  \
# 0                            want go home bored work           5
# 1  good call holding take 3 cause take 1 wa huge ...          11
# 2                   watched new moon trailer aa love           6
# 3                                           go check           2
# 4                               mammaaaaa amp sister           3
#
#    Character_Count
# 0               23
# 1               53
# 2               32
# 3                8
# 4               20

# %% [markdown]
# #### Data Cleaning

# %%
df.isna().sum()
# Out:
# Sentiment           0
# Tweets              0
# Cleaned_Tweets     47
# Word_Count          0
# Character_Count     0
# dtype: int64

# %%
df = df.dropna().reset_index()

# %%
df.isna().sum()
# Out:
# index              0
# Sentiment          0
# Tweets             0
# Cleaned_Tweets     0
# Word_Count         0
# Character_Count    0
# dtype: int64

# %% [markdown]
# #### Tokenization

# %%
sentences = df['Cleaned_Tweets'].values

sentences
# Out:
# array(['want go home bored work',
#        'good call holding take 3 cause take 1 wa huge failure',
#        'watched new moon trailer aa love', ...,
#        'gettin thangs together head san antonio wish wa goin spur game lol good',
#        'evening traffic jam', 'talk people hows everybody today'],
#       dtype=object)

# %%
words = []

for sent in sentences:
    words.extend(re.findall(r'[\w]+',sent))

words = list(set(words))

print(len(words))
# Out:
# 13914

# %%
token = Tokenizer()

token.fit_on_texts(words)

word_index = token.word_index

word_index
# Out:
# {'t': 1,
#  '0': 2,
#  'gt': 3,
#  'sex': 4,
#  'ani': 5,
#  'bee': 6,
#  'b': 7,
#  'parade': 8,
#  'john': 9,
#  'sexy': 10,
#  'patch': 11,
#  'panda': 12,
#  'menu': 13,
#  'livi': 14,
#  'poop': 15,
#  'block': 16,
#  'universe': 17,
#  'o': 18,
#  '11': 19,
#  '9': 20,
#  'grim': 21,
#  'referring': 22,
#  'discovery': 23,
#  'sang': 24,
#  '50th': 25,
#  'writerslol': 26,
#  'jordi': 27,
#  'ninaaaa': 28,
#  'netty': 29,
#  '1022': 30,
#  'september': 31,
#  'lameurijah': 32,
#  'negative': 33,
#  'damn': 34,
#  'prom': 35,
#  'ice': 36,
#  'breathe': 37,
#  'rally': 38,
#  'gcse': 39,
#  'rb': 40,
#  'outside': 41,
#  'laugh': 42,
#  'ah8u9sdig': 43,
#  'ily': 44,
#  'ikr': 45,
#  'jake': 46,
#  'crap': 47,
#  'grader': 48,
#  'virtually': 49,
#  'peacenik': 50,
#  'clay': 51,
#  'iplayer': 52,
#  '30stm': 53,
#  'khols': 54,
#  'respect': 55,
#  'andrew': 56,
#  'valencia': 57,
#  'scary': 58,
#  'noches': 59,
#  'phplurkcom': 60,
#  'loneliness': 61,
#  '20082009': 62,
#  'mouthsays': 63,
#  'gampg': 64,
#  'norah': 65,
#  'yapldn': 66,
#  'rained': 67,
#  'bouta': 68,
#  'er': 69,
#  'either': 70,
#  'holiday': 71,
#  'britain': 72,
#  'string': 73,
#  'item': 74,
#  'salon': 75,
#  '6x01': 76,
#  'beholder': 77,
#  'nickname': 78,
#  'freya': 79,
#  'jailbreaken': 80,
#  'upstairs': 81,
#  'pdhl': 82,
#  'yayyooo': 83,
#  'astronomy': 84,
#  'cluckingblossom': 85,
#  'fiekd': 86,
#  'november': 87,
#  'hbic': 88,
#  'arthur': 89,
#  'clicking': 90,
#  'require': 91,
#  'dayy': 92,
#  'roger': 93,
#  'noting': 94,
#  'clinicals': 95,
#  'itand': 96,
#  'sangha': 97,
#  'ella': 98,
#  'versus': 99,
#  'pimp': 100,
#  'nah': 101,
#  'booktime': 102,
#  'ð½ðð²ðµñð½ð¾': 103,
#  'slurpee': 104,
#  '284km': 105,
#  'far': 106,
#  'bhaha': 107,
#  't0oo': 108,
#  'personally': 109,
#  'tweeter': 110,
#  'ooka': 111,
#  'cole': 112,
#  'injected': 113,
#  'sofa': 114,
#  'lgbt': 115,
#  'actual': 116,
#  'loft': 117,
#  'buenos': 118,
#  'david': 119,
#  'fob': 120,
#  'anniversary': 121,
#  'class': 122,
#  'idont': 123,
#  'connie': 124,
#  '41': 125,
#  'ellen': 126,
#  'ohio': 127,
#  'nycquot': 128,
#  'relate': 129,
#  'seal': 130,
#  'schooltime': 131,
#  'envelope': 132,
#  'post': 133,
#  'jupy': 134,
#  'tower': 135,
#  'lola': 136,
#  'bye': 137,
#  'actor': 138,
#  'yesh': 139,
#  'swirl': 140,
#  'ableton': 141,
#  '3d': 142,
#  'worstsmfh': 143,
#  'remedy': 144,
#  'destination': 145,
#  '445pm': 146,
#  'trek': 147,
#  'condolence': 148,
#  'junina': 149,
#  'facebookand': 150,
#  'bbqs': 151,
#  'nom': 152,
#  'tweeting': 153,
#  'baloo': 154,
#  'glitzzy': 155,
#  'foster': 156,
#  'mew': 157,
#  'quotdeath': 158,
#  'starving': 159,
#  'stopmotion': 160,
#  'bery': 161,
#  'fail': 162,
#  'reorg': 163,
#  'ireland': 164,
#  'invited': 165,
#  'latin': 166,
#  'dryer': 167,
#  'hillsong': 168,
#  'pastee': 169,
#  'loooooooong': 170,
#  'sdtrk': 171,
#  'shoppin': 172,
#  'people': 173,
#  'neogaf': 174,
#  'femalesim': 175,
#  'nahh': 176,
#  'grandad': 177,
#  'constant': 178,
#  'mud': 179,
#  'shootfest': 180,
#  'mofo': 181,
#  'susan': 182,
#  'entertainment': 183,
#  'preggo': 184,
#  'curious': 185,
#  'youhpu': 186,
#  'jumprope': 187,
#  'stored': 188,
#  'cake': 189,
#  '302ð¾ð¹': 190,
#  'social': 191,
#  'ltlike': 192,
#  'drivel': 193,
#  'whaddup': 194,
#  'degree': 195,
#  's60': 196,
#  'txting': 197,
#  'predicted': 198,
#  'sla09': 199,
#  'coldstone': 200,
#  'steady': 201,
#  'gtboringlt': 202,
#  'outcome': 203,
#  'relieved': 204,
#  'biology': 205,
#  'penance': 206,
#  'marc': 207,
#  'brokenhearted': 208,
#  'kãrmes': 209,
#  'ego': 210,
#  'turtle': 211,
#  'procrastinate': 212,
#  'hippie': 213,
#  'toniteif': 214,
#  'humid': 215,
#  'remember': 216,
#  'compiling': 217,
#  'illiterate': 218,
#  'drafting': 219,
#  'cereal': 220,
#  'networknetworknetwork': 221,
#  'nitas': 222,
#  'cow': 223,
#  'darwin': 224,
#  'scrambled': 225,
#  'hummmm': 226,
#  'copper': 227,
#  'lmaooo': 228,
#  'enjoyin': 229,
#  'vamos': 230,
#  'kent': 231,
#  'jeez': 232,
#  'quotgoodquot': 233,
#  'wowit': 234,
#  'cockatails': 235,
#  'dm': 236,
#  'game': 237,
#  'nevermind': 238,
#  'ikno': 239,
#  'tanya': 240,
#  'msg': 241,
#  'attacked': 242,
#  'watchingerm': 243,
#  'yesterdaydefinitely': 244,
#  'buzz': 245,
#  'que': 246,
#  'suprisingly': 247,
#  'marathon': 248,
#  'wendi': 249,
#  '26tribbleagencycom': 250,
#  'denn': 251,
#  'tripmy': 252,
#  'bridal': 253,
#  'strive': 254,
#  'revison': 255,
#  'spiderman': 256,
#  '100euros': 257,
#  'ã': 258,
#  'infection': 259,
#  'poaching': 260,
#  'mine': 261,
#  'surely': 262,
#  'malacca': 263,
#  'spencerrrr': 264,
#  'decides': 265,
#  'migraine': 266,
#  'oasis': 267,
#  'neverrr': 268,
#  'canon': 269,
#  'ognawg': 270,
#  'dating': 271,
#  'banii': 272,
#  'headache': 273,
#  'tick': 274,
#  'arbor': 275,
#  'resetted': 276,
#  'ex': 277,
#  'summons': 278,
#  'todayy': 279,
#  'stapler': 280,
#  'whakcer': 281,
#  'brown': 282,
#  'toy': 283,
#  'birthdaychristmas': 284,
#  'oliver': 285,
#  'omgs': 286,
#  'cava': 287,
#  'affilate': 288,
#  'warbackers': 289,
#  'resisting': 290,
#  'brokencyde': 291,
#  'belmktba': 292,
#  'oceanside': 293,
#  'wax': 294,
#  'prty': 295,
#  'weekendimagine': 296,
#  'ie8': 297,
#  'cinnamon': 298,
#  'teague': 299,
#  '14': 300,
#  'swift': 301,
#  'mussel': 302,
#  'effect': 303,
#  'noones': 304,
#  'drill': 305,
#  'greasy': 306,
#  '2g': 307,
#  'sicky': 308,
#  'diddy': 309,
#  'shelf': 310,
#  'previous': 311,
#  'callouses': 312,
#  'commit': 313,
#  'pakiligin': 314,
#  'isiklikke': 315,
#  'arf': 316,
#  'exact': 317,
#  'pc': 318,
#  'chá': 319,
#  'oow': 320,
#  'adays': 321,
#  't2': 322,
#  'prussia': 323,
#  'quotpuddlesquotlisting': 324,
#  'anticipation': 325,
#  'nighshift': 326,
#  'busyif': 327,
#  'jumpnows': 328,
#  'cobracam': 329,
#  'insurance': 330,
#  'activity': 331,
#  'asante': 332,
#  'loveliest': 333,
#  'tamale': 334,
#  'squeezing': 335,
#  'vinyl': 336,
#  'emily': 337,
#  'nopee': 338,
#  'massaging': 339,
#  'officially': 340,
#  'nathans': 341,
#  'singer': 342,
#  'fatty': 343,
#  'image': 344,
#  'locked': 345,
#  'sht': 346,
#  'jwg': 347,
#  'aunt': 348,
#  'deathi': 349,
#  'thesechipsare': 350,
#  'sam': 351,
#  'aaaaaaaaa': 352,
#  'completing': 353,
#  'passionately': 354,
#  'heyyyyy': 355,
#  'noone': 356,
#  'passport': 357,
#  'haha': 358,
#  'ahhtheres': 359,
#  'aber': 360,
#  'mixed': 361,
#  'lmyn': 362,
#  'boo': 363,
#  'motivation': 364,
#  '930yay': 365,
#  'opening': 366,
#  'wrestling': 367,
#  'thisquot': 368,
#  'poppy': 369,
#  'anytime': 370,
#  'cost': 371,
#  'ubuntu': 372,
#  'sloooow': 373,
#  'excellence': 374,
#  'prize': 375,
#  'communication': 376,
#  'realbetter': 377,
#  'ddnt': 378,
#  'holyrood': 379,
#  'girlthe': 380,
#  '715': 381,
#  'bella': 382,
#  'teecookie': 383,
#  'worked': 384,
#  '1sto': 385,
#  'rigght': 386,
#  'gentleman': 387,
#  'itsd': 388,
#  'lotion': 389,
#  'motwani': 390,
#  'pouting': 391,
#  'language': 392,
#  'clintooooon': 393,
#  'shaped': 394,
#  'adobe': 395,
#  'freazing': 396,
#  'news': 397,
#  'orientated': 398,
#  'duffle': 399,
#  'innocent': 400,
#  'practise': 401,
#  'advance': 402,
#  'heater': 403,
#  'corr': 404,
#  'delphic': 405,
#  'boondock': 406,
#  'loggins': 407,
#  'road': 408,
#  'amazing': 409,
#  'tks': 410,
#  'airplane': 411,
#  'followin': 412,
#  'lold': 413,
#  'lovelovelove': 414,
#  'mcallen': 415,
#  'fresno': 416,
#  'tote': 417,
#  'strange': 418,
#  'workcry': 419,
#  '23': 420,
#  'scrabble': 421,
#  'bittorrent': 422,
#  'mummy': 423,
#  'dot': 424,
#  'slamdrunk': 425,
#  'hailing': 426,
#  'hulk': 427,
#  'vactive': 428,
#  'saladmy': 429,
#  '3647': 430,
#  'bomel': 431,
#  'addicting': 432,
#  'horseshoe': 433,
#  'savedquot': 434,
#  'airfrance': 435,
#  'fwah': 436,
#  'stemcell': 437,
#  'pharcyde': 438,
#  'coast': 439,
#  'tommorow': 440,
#  'iatkos': 441,
#  'regeneration': 442,
#  'nov26': 443,
#  'digital': 444,
#  'louis': 445,
#  'fromi': 446,
#  'whack': 447,
#  'itll': 448,
#  'datastore': 449,
#  'zeppolis': 450,
#  'programming': 451,
#  'chainreaction': 452,
#  'exciting': 453,
#  'madison': 454,
#  'melo': 455,
#  'named': 456,
#  'pk': 457,
#  '90210': 458,
#  'yougrandaunty': 459,
#  'tendo': 460,
#  'moreso': 461,
#  'bored': 462,
#  'anticipated': 463,
#  'madretext': 464,
#  'lbp': 465,
#  '150people': 466,
#  'melanies': 467,
#  'lied': 468,
#  'hayfever': 469,
#  'cant': 470,
#  'sorta': 471,
#  'loadsa': 472,
#  'jay': 473,
#  'derailing': 474,
#  'thereeureka': 475,
#  'uk': 476,
#  'glamour': 477,
#  'hectic': 478,
#  'bahaha': 479,
#  'awesome': 480,
#  'streak': 481,
#  'killng': 482,
#  'adam': 483,
#  'ra': 484,
#  'embedded': 485,
#  'bonnaroo': 486,
#  'blond': 487,
#  'pero': 488,
#  'dp': 489,
#  'roadtrip': 490,
#  'glee': 491,
#  'tomoro': 492,
#  'conchords': 493,
#  'mikeee': 494,
#  'partyin': 495,
#  'understanding': 496,
#  'backside': 497,
#  'vampirebutttt': 498,
#  'sbrin': 499,
#  'conflict': 500,
#  'regard': 501,
#  'chillin': 502,
#  'workshop': 503,
#  'mobile': 504,
#  'randomly': 505,
#  'roomi': 506,
#  'stomach': 507,
#  'shittttttt': 508,
#  'cc': 509,
#  'tonight': 510,
#  'stroke': 511,
#  'due': 512,
#  'tres': 513,
#  'readin': 514,
#  'kimberley': 515,
#  'mage': 516,
#  'kkkk': 517,
#  'dforum': 518,
#  'helenes': 519,
#  'consider': 520,
#  'hazy': 521,
#  'certified': 522,
#  'ovum': 523,
#  'link': 524,
#  'prison': 525,
#  'urgently': 526,
#  'demmi': 527,
#  'csv': 528,
#  'babysit': 529,
#  'gto': 530,
#  'mileyyyyy': 531,
#  'sti': 532,
#  'watched': 533,
#  'uuuggghh': 534,
#  'egg': 535,
#  'scentsy': 536,
#  'favesthanks': 537,
#  'jordan': 538,
#  'cousin': 539,
#  'babybump': 540,
#  'crab': 541,
#  'yarg': 542,
#  'twititionâ': 543,
#  'googling': 544,
#  'life': 545,
#  'bank': 546,
#  'ama': 547,
#  'inmortal': 548,
#  'pageez': 549,
#  'awful': 550,
#  'lit': 551,
#  'warrrm': 552,
#  'yous': 553,
#  'flts': 554,
#  'xbox': 555,
#  'root': 556,
#  'wooty': 557,
#  'partial': 558,
#  'thunder': 559,
#  'rely': 560,
#  'daily': 561,
#  'emoness': 562,
#  'total': 563,
#  'cllge': 564,
#  'breather': 565,
#  'cannon': 566,
#  'shaqtus': 567,
#  'legend': 568,
#  'grandmother': 569,
#  'patd': 570,
#  'roomy': 571,
#  'ashlyn': 572,
#  'ass': 573,
#  'jeezy': 574,
#  'sip': 575,
#  '9ish': 576,
#  'nothing': 577,
#  'comedian': 578,
#  'network': 579,
#  'dphresh': 580,
#  '135kg': 581,
#  'burn': 582,
#  'writing': 583,
#  'quincy': 584,
#  'keepin': 585,
#  'purple': 586,
#  'forgive': 587,
#  'hdmi': 588,
#  'x': 589,
#  'jinx': 590,
#  'regular': 591,
#  'swimming': 592,
#  'philly': 593,
#  'charlieeee': 594,
#  'sampling': 595,
#  'stomping': 596,
#  'wished': 597,
#  'totally': 598,
#  'trail': 599,
#  'ryan': 600,
#  'narrow': 601,
#  'quack': 602,
#  'county': 603,
#  'calledyay': 604,
#  'mesad': 605,
#  'foxysmile': 606,
#  'ish': 607,
#  'obscura': 608,
#  'formidable': 609,
#  'recovery': 610,
#  'dreamtheater': 611,
#  'runic': 612,
#  'european': 613,
#  'cristiano': 614,
#  'maui': 615,
#  'death': 616,
#  'yoo': 617,
#  'gene': 618,
#  'grouped': 619,
#  'yerp': 620,
#  'creating': 621,
#  'navy': 622,
#  'hosed': 623,
#  'yesterdayfirst': 624,
#  'auction': 625,
#  'depressioninduced': 626,
#  'white': 627,
#  'insane': 628,
#  'asleep': 629,
#  'yummu': 630,
#  'nighclub': 631,
#  'corky': 632,
#  'ughhhh': 633,
#  'quotthank': 634,
#  'stupid': 635,
#  'mish': 636,
#  'jejejeje': 637,
#  'army': 638,
#  'recruiter': 639,
#  'anger': 640,
#  'jaklar': 641,
#  'uhhhhhhh': 642,
#  'ph': 643,
#  'woooo': 644,
#  'swiming': 645,
#  'ming': 646,
#  'barbeque': 647,
#  'meow': 648,
#  'argentinian': 649,
#  'mp': 650,
#  'castle': 651,
#  'g4': 652,
#  'wear': 653,
#  'glad': 654,
#  'rhymed': 655,
#  'worst': 656,
#  'pom': 657,
#  'socialistgreen': 658,
#  'shorter': 659,
#  'nest': 660,
#  'yard': 661,
#  'salad': 662,
#  'greatful': 663,
#  '41after': 664,
#  '10mpg': 665,
#  'diggshouts': 666,
#  'believe': 667,
#  'quotlily': 668,
#  'sheetover': 669,
#  'mkpgdecide': 670,
#  'nã³i': 671,
#  'disturbing': 672,
#  'destroy': 673,
#  'havnt': 674,
#  'creativity': 675,
#  'quotvoices': 676,
#  'colby': 677,
#  'networkthis': 678,
#  'justin': 679,
#  'a330200': 680,
#  'twink': 681,
#  'vincent': 682,
#  'elphaba': 683,
#  'picnic': 684,
#  'daythis': 685,
#  'slytherin': 686,
#  'pho': 687,
#  'bloodsport': 688,
#  'shutter': 689,
#  'deceased': 690,
#  'sesame': 691,
#  'fer': 692,
#  'guessing': 693,
#  'spice': 694,
#  'pain': 695,
#  'julian': 696,
#  'mag': 697,
#  'taught': 698,
#  'belong': 699,
#  'discussing': 700,
#  'westcoast': 701,
#  'managed': 702,
#  'amandapalmer': 703,
#  'jim': 704,
#  'ridic': 705,
#  'cova': 706,
#  'woh': 707,
#  'terminator': 708,
#  'bash': 709,
#  'govt': 710,
#  'dodgeball': 711,
#  'hollie': 712,
#  'fucki': 713,
#  'enjoying': 714,
#  '5dmarkii': 715,
#  'gecko': 716,
#  'layer': 717,
#  'exboss': 718,
#  'came': 719,
#  'mjolnir': 720,
#  'seo': 721,
#  'pan': 722,
#  'jhb': 723,
#  'puzzle': 724,
#  'neighbor': 725,
#  'listthe': 726,
#  'tait': 727,
#  'died': 728,
#  'replying': 729,
#  'puree': 730,
#  'likewatching': 731,
#  'athens': 732,
#  'screaming': 733,
#  'lotsa': 734,
#  '4x1': 735,
#  'hasta': 736,
#  'traurig': 737,
#  'jeremy': 738,
#  'escaping': 739,
#  'snoozing': 740,
#  'itv': 741,
#  'blather': 742,
#  'disconnected': 743,
#  'could': 744,
#  'jersey': 745,
#  'telefon': 746,
#  'twisted': 747,
#  'judging': 748,
#  'hence': 749,
#  'browsin': 750,
#  'sleepy': 751,
#  'motion': 752,
#  'arson': 753,
#  'nextmmmmmm': 754,
#  '30': 755,
#  'ham': 756,
#  'gg': 757,
#  'shaw': 758,
#  'hooraybut': 759,
#  'optns': 760,
#  'nasa': 761,
#  'yaknow': 762,
#  'baliiiiii': 763,
#  '250': 764,
#  'suicide': 765,
#  'optimism': 766,
#  'norwich': 767,
#  '46': 768,
#  'constituency': 769,
#  'á': 770,
#  'ferb': 771,
#  'blush': 772,
#  'correct': 773,
#  'postal': 774,
#  'bol': 775,
#  'perform': 776,
#  'painful': 777,
#  'amoung': 778,
#  'lovely': 779,
#  'muy': 780,
#  'galini': 781,
#  'hour': 782,
#  'shreveport': 783,
#  'suggestionsthere': 784,
#  'evidently': 785,
#  'concentrate': 786,
#  'hopped': 787,
#  'wks': 788,
#  'makin': 789,
#  'mary': 790,
#  'absofuckinglutely': 791,
#  'kthnkxbai': 792,
#  'recovering': 793,
#  'confirmation': 794,
#  'catchin': 795,
#  'hacving': 796,
#  'pooley': 797,
#  'zombie': 798,
#  'thankx': 799,
#  'youngest': 800,
#  'typo': 801,
#  'yeer': 802,
#  'sosoumso': 803,
#  'em': 804,
#  'pursuit': 805,
#  'aaarrgghhhh': 806,
#  'nandini': 807,
#  'goodafternon': 808,
#  'secret': 809,
#  'pinch': 810,
#  'sooooooooooooo': 811,
#  'citin': 812,
#  'platinum': 813,
#  'hun': 814,
#  'quotnude': 815,
#  'expect': 816,
#  'access': 817,
#  'blame': 818,
#  'cockpit': 819,
#  'decent': 820,
#  'frosting': 821,
#  'tart': 822,
#  'wedding': 823,
#  'hrmm': 824,
#  'omg': 825,
#  'shiza': 826,
#  'impending': 827,
#  'blazin': 828,
#  'gardenia': 829,
#  'sickim': 830,
#  'fire': 831,
#  'moving': 832,
#  'highly': 833,
#  'sadder': 834,
#  'float': 835,
#  '4real': 836,
#  'bench': 837,
#  'woowooowoo': 838,
#  'shortage': 839,
#  'katelynn': 840,
#  'sounded': 841,
#  'flyer': 842,
#  'sil': 843,
#  'uihauihauihiuah': 844,
#  'sanwich': 845,
#  'fi': 846,
#  'devistated': 847,
#  'adsi': 848,
#  'procrastinating': 849,
#  'dharma': 850,
#  'today': 851,
#  'dialer': 852,
#  'woooooooo': 853,
#  'carolina': 854,
#  'heartless': 855,
#  'household': 856,
#  'asshole': 857,
#  'efficiency': 858,
#  'ecclesiastes': 859,
#  'arises': 860,
#  'deepheat': 861,
#  'maxwell': 862,
#  'childstudies': 863,
#  't5': 864,
#  'quotbelieve': 865,
#  'wiff': 866,
#  'squeal': 867,
#  'disable': 868,
#  '150': 869,
#  'proud': 870,
#  'hahah': 871,
#  '2moro': 872,
#  'uriza': 873,
#  'recommended': 874,
#  'excited': 875,
#  'cursing': 876,
#  'tickletuesday': 877,
#  'easiest': 878,
#  'awesomenessi': 879,
#  'downknowing': 880,
#  'screen': 881,
#  'shatner': 882,
#  'camden': 883,
#  'stevens': 884,
#  'pooped': 885,
#  'nadzi': 886,
#  'asleepp': 887,
#  'apt': 888,
#  'fax': 889,
#  'speidi': 890,
#  'msp': 891,
#  'childrens': 892,
#  'dick': 893,
#  'huhuhuhu': 894,
#  'seewell': 895,
#  'port': 896,
#  'tyson': 897,
#  'sid': 898,
#  'jb': 899,
#  'bar': 900,
#  'dayrip': 901,
#  'suga': 902,
#  '3week': 903,
#  'jammin': 904,
#  'ghostwriter': 905,
#  'skinny': 906,
#  'wud': 907,
#  'copenhagen': 908,
#  'quot': 909,
#  'pg13': 910,
#  'smart': 911,
#  'tripoli': 912,
#  'cram': 913,
#  'legacyquot': 914,
#  'â2': 915,
#  'seeeeee': 916,
#  'fonzarellis': 917,
#  'thankiies': 918,
#  'breakdance': 919,
#  'vc': 920,
#  'warmth': 921,
#  'quotstompquot': 922,
#  'graduation': 923,
#  'blessing': 924,
#  'roomie': 925,
#  'coffe': 926,
#  'tushar': 927,
#  'weekend': 928,
#  'quotpaper': 929,
#  'arrived': 930,
#  'napa': 931,
#  'ze': 932,
#  'cassiopeia': 933,
#  'location': 934,
#  'blahg': 935,
#  'ffall': 936,
#  'commoner': 937,
#  'stranger': 938,
#  'sleep': 939,
#  'v': 940,
#  'hilly': 941,
#  'imeem': 942,
#  'crooked': 943,
#  'hellah': 944,
#  'charleston': 945,
#  'shoe': 946,
#  'andrea': 947,
#  'motivating': 948,
#  'milles': 949,
#  'rome': 950,
#  'whts': 951,
#  'nhan': 952,
#  'lakers': 953,
#  'brookekidd': 954,
#  'strand': 955,
#  'slumber': 956,
#  'cpl': 957,
#  'hypocriteslol': 958,
#  'alright': 959,
#  'ganda': 960,
#  'toe': 961,
#  'crash': 962,
#  'axe': 963,
#  'ð²ñðµð¼ñ': 964,
#  'lateee': 965,
#  'bucause': 966,
#  'fetched': 967,
#  'budapest': 968,
#  'biddy': 969,
#  'cloud': 970,
#  'assignment': 971,
#  'cupcake': 972,
#  'syke': 973,
#  'humanity': 974,
#  'moovarolage': 975,
#  'newsscarey': 976,
#  'throatpunches': 977,
#  'grooming': 978,
#  'tien': 979,
#  'compare': 980,
#  'banjo': 981,
#  'lovewhen': 982,
#  'washed': 983,
#  'share': 984,
#  'hawt': 985,
#  'humbug': 986,
#  'reason': 987,
#  'khã¹ng': 988,
#  'huhu': 989,
#  'premiere': 990,
#  'station': 991,
#  'lick': 992,
#  'wishing': 993,
#  'grown': 994,
#  'gia': 995,
#  'kenyon': 996,
#  'circumstance': 997,
#  'inconsiderate': 998,
#  'samurai': 999,
#  'bell': 1000,
#  ...}

# %%
sequences = token.texts_to_sequences(sentences)

sequences
# Out:
# [[8047, 4447, 2901, 462, 3743],
#  [10474, 12075, 10593, 4667, 9013, 13058, 4667, 6815, 10355, 8200, 6575],
#  [533, 13820, 4986, 12372, 7264, 11172],
#  [4447, 3610],
#  [10245, 2843, 4344],
#  [9676, 2638, 7749, 2330, 987, 6323],
#  [11348, 9369, 5612, 4845, 1423, 6381, 13797, 4318, 10859, 4379],
#  [3718, 4893, 2204, 4848, 13771, 6507, 1631],
#  [3661, 1425, 4845, 8071, 4327, 2843, 11900, 9025],
#   3610,
#   12444,
#   5013,
#   6783,
#   12615,
#   6571,
#   4736,
#   2901,
#   12199],
#  [12795, 3218, 4447, 939, 6507, 6910, 8047, 7229, 10096, 12516],
#  [3299, 10355, 7326, 13820, 12962, 4934, 2422, 2429],
#  [9386, 3299, 7001],
#  [10748, 10355, 6223, 11847, 5612, 10355, 9529, 13656, 11172, 7354],
#  [9351, 9041, 9710, 13037, 7564],
#  [5327, 4845, 7688, 8071, 12750, 13820, 11108, 8516, 12479, 13820, 5658],
#  [3707, 1891, 1923, 1548, 13907, 7374, 10360, 13146],
#  [10227,
#   8099,
#   10474,
#   8972,
#   4764,
#   11272,
#   11361,
#   2394,
#   11445,
#   10684,
#   2472,
#   1263,
#   7969,
#   11478],
#  [6534, 9417, 4845, 10520, 10355, 7472, 1248, 10068],
#  [7749,
#   1320,
#   3162,
#   3661,
#   12378,
#   5261,
#   3661,
#   5080,
#   12615,
#   7682,
#   12917,
#   4845,
#   10841,
#   1527,
#   6100],
#  [8562, 4141, 4704, 1713, 9676, 13146, 13148, 10524, 8562, 10704, 5941],
#  [8471, 10474, 10520, 13384, 1245, 2068, 13220],
#  [13202, 5572, 8099, 7229, 10524, 6943, 864],
#  [6085, 4432, 12727, 10743],
#  [11172, 11294, 3803, 5867],
#  [11663, 10913, 11866, 6986, 13834],
#  [11857, 3167, 5757, 6211, 2228, 5261],
#  [8102, 782, 7114, 8588],
#  [13202, 8099, 2300, 3765, 4447, 3743],
#  [12430, 10227, 6006, 1670],
#  [13626,
#   12540,
#   343,
#   12638,
#   1709,
#   310,
#   2631,
#   5454,
#   6078,
#   11033,
#   2300,
#   7949,
#   4704,
#   12591],
#  [13079, 4129, 13197, 6706, 2843, 1623, 3818, 6783, 1177, 1964, 4800, 7388],
#  [6746, 2824, 3395, 8294, 13827, 7635, 5840],
#  [340, 3519, 7360, 10524, 913, 3541, 7229],
#  [7953, 4764, 4283, 8319, 10311, 409, 9413, 8063, 11857, 4322, 12423, 2567],
#  [3080,
#   7897,
#   1808,
#   728,
#   851,
#   11857,
#   4322,
#   5261,
#   2220,
#   4667,
#   10360,
#   13026,
#   10360,
#   7749,
#   1808],
#  [10355, 11033, 10474, 6507, 11536],
#  [1707, 1498, 6486, 2952, 2441, 6972, 4845, 290, 13003],
#  [12426, 13653, 2611, 11212, 12504, 6345, 5736, 9605, 4283, 7472, 3433, 7721],
#  [6870,
#   7515,
#   9294,
#   3743,
#   3380,
#   10129,
#   3380,
#   6039,
#   9351,
#   3570,
#   9661,
#   7905,
#   11172,
#   5612],
#  [11442, 8809, 4845, 6458, 10144, 1634, 5757, 5279, 8012, 11473, 8195, 527],
#  [9221, 10621, 589],
#  [5327],
#  [6419,
#   10080,
#   6376,
#   10737,
#   10355,
#   480,
#   13447,
#   5864,
#   3313,
#   12449,
#   6776,
#   3516,
#   13820,
#   5551,
#   9535],
#  [5612, 5596, 7969],
#  [3080, 11031, 4236, 1957, 12984, 3047, 9277, 2445],
#  [520, 5261, 10631, 7114, 3499, 11835, 10631, 7114, 2163, 12937, 2163],
#  [13251, 11478, 7818, 4447, 13037],
#  [10474, 11827, 13146, 11857, 5279, 4447, 7629, 10344, 11730, 7834, 7475],
#  [7969, 4011, 1127, 8047],
#  [5222, 1888, 8102, 3697, 12937, 227, 2003, 8517],
#  [13850],
#  [8824, 4603, 12794, 4845, 12682, 5261, 1216, 13292],
#  [13221, 3570, 2648, 7114, 7229],
#  [9618, 4845, 7749, 9368, 8588, 5134, 8681, 8471, 13452, 13660],
#  [2942, 3516, 3014, 6028, 9176, 9506, 12337, 6447, 653, 4845, 9521, 946, 9454],
#  [7953,
#   3174,
#   9661,
#   7749,
#   11857,
#   4322,
#   1377,
#   10941,
#   7209,
#   561,
#   173,
#   3581,
#   6083],
#  [6852, 3424, 4796, 2322, 9574, 8319, 13238, 4796, 6073],
#  [4106, 1589, 13035, 1736, 3509, 8550, 13035],
#  [11214, 551, 3697, 2516],
#  [953, 8, 13130, 12860, 9797, 9993, 953],
#  [9250,
#   13119,
#   2708,
#   3560,
#   12078,
#   11238,
#   4948,
#   5814,
#   358,
#   1670,
#   2736,
#   6010,
#   8185],
#  [470, 4845, 2913],
#  [3743, 12725, 5972, 2901, 7894, 13557, 6894, 3942, 12976, 3570],
#  [5327, 2734, 7924, 9935, 13169, 7785, 4542, 11172, 2362],
#  [6242, 5272, 9945, 2901, 8338, 5958, 11798, 3794, 12555, 2745, 8997, 1323],
#  [10474, 8709],
#  [5630,
#   13252,
#   13626,
#   4845,
#   3682,
#   12075,
#   9701,
#   13820,
#   3187,
#   4754,
#   13146,
#   10992],
#  [5899,
#   2302,
#   12700,
#   5757,
#   1468,
#   6894,
#   7508,
#   8269,
#   8099,
#   4260,
#   470,
#   5567,
#   1238,
#   4704],
#  [1739, 10567, 11686, 10474, 4704],
#  [744, 1034, 12408, 11732, 5612, 11172],
#  [9676,
#   13626,
#   13148,
#   744,
#   2236,
#   3598,
#   12476,
#   2912,
#   9867,
#   6545,
#   12830,
#   4322,
#   1127],
#  [8407, 8669, 3743, 11923, 7114, 782, 11348],
#  [4845, 11732, 11172, 13293, 4322, 3174, 10174, 4845, 11172],
#  [11172, 4074, 10227, 8809, 7969, 2152],
#  [5864, 5171, 2068, 5327, 4722],
#  [13473,
#   10382,
#   11564,
#   12211,
#   13380,
#   13523,
#   9714,
#   11993,
#   9498,
#   9032,
#   4263,
#   6769],
#  [751,
#   9592,
#   6378,
#   4045,
#   3053,
#   9041,
#   7360,
#   12275,
#   10897,
#   6092,
#   1349,
#   6747,
#   2801,
#   9041],
#  [12479, 5543, 122, 12390, 6627, 11006, 7568, 5646, 2068],
#  [3918, 8116, 5137, 4667, 2220, 7210, 7749],
#  [7028, 9661, 7749, 8848, 9535, 5747, 13556, 7375, 3743],
#  [9676, 6507, 12722, 11556, 9916, 3162, 3453, 4845],
#  [7510, 4920, 11743, 13820, 5945, 4845, 10520, 8588, 9369, 1927],
#  [5279, 10360, 12239],
#  [7749,
#   831,
#   7359,
#   2330,
#  [7289, 11348, 10355, 2266, 13292, 3016],
#  [3174, 10360, 13251, 8766, 5554, 3756],
#  [4318,
#   9041,
#   8099,
#   10227,
#   409,
#   8063,
#   10162,
#   8420,
#   8490,
#   2901,
#   5555,
#   12474,
#   6529],
#  [3932,
#   6742,
#   13038,
#   4067,
#   11092,
#   12632,
#   1103,
#   3581,
#   8577,
#   2692,
#   669,
#   9107,
#   9386],
#  [13252, 7957, 10798, 11348, 10474, 7799],
#  [7114],
#  [4845,
#   654,
#   6821,
#   10660,
#   10311,
#   8240,
#   10355,
#   4704,
#   7359,
#   13080,
#   4845,
#   9617,
#   7050,
#   3320,
#   13849,
#   603],
#  [8047,
#   2103,
#   12511,
#   2901,
#   11549,
#   4736,
#   510,
#   7629,
#   1127,
#   8753,
#   6571,
#   4845,
#   11275,
#   5327,
#   11798,
#   3932],
#  [9661,
#   1435,
#   6941,
#   5013,
#   10474,
#   5479,
#   12235,
#   1935,
#   7749,
#   4079,
#   9699,
#   11348,
#   3682,
#   11172,
#   12061],
#  [7685, 7430, 12615, 7685, 2571, 8319, 9661, 104],
#  [10848,
#   10621,
#   8905,
#   3697,
#   1808,
#   8808,
#   1600,
#   41,
#   2015,
#   1477,
#   5942,
#   9435,
#   9068,
#   6394,
#   12464,
#   7657,
#   5676],
#  [4845, 13007, 7984, 11348, 5422, 7079, 10792, 4608, 10984],
#  [10984, 13820, 5636],
#  [3344, 7182, 360, 10669, 2668, 1493, 10377, 3604, 470, 7173, 5261],
#  [12864, 5676, 10979],
#  [9218, 6591, 13030, 8588],
#  [13626, 5543, 4470, 9041, 1216, 162, 122],
#  [10474,
#   9571,
#   6323,
#   363,
#   5366,
#   9691,
#   4845,
#   5659,
#   12615,
#   6447,
#   9041,
#   4845,
#   1216,
#   9785],
#  [1216, 1127],
#  [524, 10660, 8458],
#  [8777, 9365, 13852, 3697, 3581, 7957, 7229, 12914, 11304],
#  [7953, 11920, 1397, 4842, 2468, 4045, 9041],
#  [358, 9654, 1670, 5327, 12144],
#  [8319, 13807, 12725, 10360, 7657, 6853, 8645, 470, 5567, 1216, 9983],
#  [7657, 311, 4735, 6590, 10312, 7960],
#  [10474, 13202, 7590],
#  [3291, 755, 782, 5596, 5864, 1793, 5134, 13150, 924, 11172, 9450],
#  [2220,
#   3743,
#   9041,
#   7657,
#   12511,
#   2901,
#   7657,
#   1808,
#   2447,
#   7822,
#   11043,
#   5864,
#   9041,
#   7657,
#   10360,
#   3564,
#   6447,
#   12294],
#  [11033, 13148, 11857, 6211, 1153, 13539, 3019],
#  [5560, 6247, 939, 6775, 3419, 1127, 7229, 8050, 10474, 10798],
#  [5763, 11262, 5543, 2567],
#  [13148, 11102, 5871, 11493, 524, 8099, 6769, 10144, 4704, 8606, 5945, 6331],
#  [3174, 8319, 2112, 12750, 1094, 1788, 4508, 4845, 5309, 9294, 5676],
#  [4379, 11033, 470, 1535, 11887],
#  [1627,
#   5398,
#   10076,
#   4447,
#   10027,
#   4845,
#   5791,
#   3743,
#   13169,
#   6731,
#   9535,
#   6910],
#  [13626,
#   7050,
#   5676,
#   8626,
#   9661,
#   7657,
#   13051,
#   6036,
#   1029,
#   5757,
#   5567,
#   12511,
#   6940,
#   12638],
#  [10355, 5899, 12235, 4393],
#  [7935,
#   779,
#   3048,
#   12996,
#   7463,
#   10325,
#   11033,
#   13146,
#   165,
#   466,
#   2203,
#   11214,
#   8985,
#   10582],
#  [11033, 11426],
#  [10532, 9041, 1837, 4365, 4845, 6052, 6247, 8099, 7969, 5519, 8320],
#  [12615, 9132, 12917, 3813, 6381, 12214, 12225, 10843, 11453, 4447, 471],
#  [4845, 4842, 12433],
#  [10737, 4045, 11370],
#  [4074, 13037, 8407],
#  [13148, 4300, 5476, 10144, 11857, 12615],
#  [10474,
#   10522,
#   9430,
#   10808,
#   1499,
#   7890,
#   7957,
#   10855,
#   5380,
#   1350,
#   7229,
#   1236,
#   2469],
#  [1628,
#   9041,
#   5059,
#   13557,
#   1037,
#   2843,
#   12907,
#   11669,
#   7375,
#   8881,
#   5469,
#   2011,
#   3123,
#   6507,
#   10311,
#   12184,
#   4318,
#   9041],
#  [7935, 5039, 7969, 598, 5202],
#  [12718,
#   5279,
#   6397,
#   8809,
#   4322,
#   5757,
#   153,
#   7050,
#   5676,
#   6894,
#   1248,
#   9025,
#   12615],
#  [13824,
#   9535,
#   13824,
#   7249,
#   10724,
#   4396,
#   2060,
#   1801,
#   2429,
#   7935,
#   10482,
#   12194,
#   11214],
#  [5976, 875, 1399, 5078, 9261, 358, 9935],
#  [1190, 259, 3682, 9756, 470, 5567, 1850, 4447, 8439],
#  [8047, 6677, 189, 13040, 12629, 6092],
#  [11172, 11746, 10660],
#  [6384, 10355, 1544, 1392, 6698, 1544, 3111, 6968, 6384, 12497, 11348],
#  [10360, 2282],
#  [1623, 13169, 8102, 2060, 10434, 10601, 2068],
#  [3610, 11339, 536, 9778, 10880],
#  [10984, 10249, 8501, 453],
#  [7341,
#   3410,
#   3607,
#   11239,
#   7657,
#   1808,
#   7657,
#   283,
#   4077,
#   9013,
#   480,
#   10520,
#   8501,
#   453],
#  [5030, 2300, 4926],
#  [5139, 1485],
#  [2901, 3743],
#  [559, 6323, 11178, 5327, 559],
#  [7020, 11172],
#  [2068, 12615, 10474, 13202, 7960],
#  [1153, 3541, 7229, 6211, 583, 6637, 261, 4375, 2365],
#  [3516,
#   5059,
#   2421,
#   10355,
#   3263,
#   6440,
#   2236,
#   7407,
#   4845,
#   6305,
#   3765,
#   3495,
#   6950,
#   6373,
#   1320],
#  [3516, 5519, 106, 12852],
#  [11825, 8719, 11379, 5676],
#  [6870, 1216, 2904],
#  [8839, 7848, 13454, 9025, 8950, 9090, 3110, 11821, 662, 3015],
#  [2974, 4489, 1466, 7657, 4667, 13202, 2843, 470, 5944, 629],
#  [4322, 11276, 12907, 13080, 3697, 9037, 11276, 6052, 13324, 9269, 12145],
#  [470, 2684, 5903, 9041, 13896, 9701, 4845, 10824, 4392, 41],
#  [3862, 10966, 10511],
#  [470,
#   3351,
#   939,
#   1592,
#   1684,
#   1736,
#   10360,
#   7114,
#   2330,
#   10524,
#   12479,
#   1833,
#   3708],
#  [3895, 3661, 7224, 13531, 1495],
#  [13146,
#   9945,
#   8102,
#   11033,
#   4318,
#   2981,
#   4845,
#   10520,
#   4215,
#   6171,
#   13886,
#   1127,
#   10360,
#   11518,
#   2843,
#   10360,
#   13146],
#  [10798, 10798, 13244, 4862, 5134, 6393, 3815, 2567, 4667, 5102],
#  [12871, 12605, 5261, 4447, 11988, 6578, 11348, 589],
#  [3743, 7114, 851],
#  [2330, 7935, 8972, 173, 11522, 12615, 6545, 2040],
#  [462, 9047, 7409, 7209, 5579, 12432, 2684, 11947, 9365, 7359],
#  [7784, 11140, 6742, 4592, 781, 9185, 8407, 6032, 12144, 6029, 11925],
#  [9549,
#   7674,
#   6551,
#   13067,
#   8047,
#   4667,
#   4767,
#   4938,
#   11787,
#   9867,
#   11984,
#   9976,
#   10848,
#   4845,
#   11719],
#  [851, 4754, 9041, 11478, 13058, 5612, 6247, 6247, 5261, 10174],
#  [11172, 13820, 1808],
#  [7657, 7, 3260, 6447, 2442, 8047, 6815, 1057, 3682, 5924, 6447],
#  [11172, 831, 3103, 8099],
#  [4322, 9486, 9312, 4307, 510, 12851, 5718, 9009],
#  [9559,
#   11857,
#   13169,
#   8501,
#   9450,
#   13109,
#   6032,
#   12032,
#   236,
#   13080,
#   1238,
#   236,
#   8780],
#  [11857, 5080, 10474, 13498],
#  [5374, 4704, 9041, 470, 4447, 5310, 4862],
#  [7463, 2992, 9723, 6430, 8047, 2829, 6769, 3682, 11887],
#  [8418, 3564, 3743, 363, 3299, 12267, 2789],
#  [12615,
#   8709,
#   1548,
#   2330,
#   10701,
#   7590,
#   8336,
#   4845,
#   3265,
#   7590,
#   12661,
#   7224,
#   13531,
#   7969,
#   8709],
#  [11172, 4136, 10360, 8871, 10474, 939, 13058],
#  [3344, 13315, 1732, 7729, 2236, 9617],
#  [6323, 7114, 173, 1349, 8844],
#  [11712, 5385, 510, 11510, 9041, 5731, 6571, 470, 7969, 2480, 9580, 928],
#  [7953, 1278],
#  [10474, 13452, 7749, 6776, 8909, 6381, 408, 12215],
#  [4840, 7753, 3661, 2860, 3618, 10040, 7651, 8809, 5549, 991],
#  [2236, 2153, 1487, 8099, 9222, 1487, 7969, 8673],
#  [1185, 13169, 7129, 12382, 2327],
#  [12305, 3318, 10355, 9592, 4337, 1399, 10474],
#  [10474, 10631, 7348, 12498, 2631],
#  [7953, 8681, 5910, 472, 7480, 2966, 5435, 153],
#  [1874, 7657, 1057],
#  [3226,
#   9592,
#   9242,
#   1201,
#   6222,
#   3132,
#   13051,
#   5563,
#   2140,
#   9242,
#   7657,
#   6222,
#   9710,
#   3132,
#   13051,
#   11835],
#  [3661, 10737, 10312, 1837, 4231, 10355, 1141, 6189, 7229],
#  [4717, 7827],
#  [667, 6216, 8319, 7156, 11405, 8099, 4021],
#  [9386, 5279, 1127, 4322, 13169],
#  [11442, 13820, 10144, 5612, 1935, 1220, 7711, 10360, 10527],
#  [10274, 10306, 13534, 4476, 4747],
#  [1443, 185],
#  [10643, 11732, 11857, 12168],
#  [8258,
#   6044,
#   3282,
#   10474,
#   987,
#   11857,
#   12615,
#   5080,
#   8555,
#   4920,
#   9312,
#   4845,
#   7682,
#   11377,
#   1168,
#   6447,
#   1320],
#  [10710, 12615, 5261, 11902],
#  [13820, 3003, 9961, 6507, 13202],
#  [10355,
#   13601,
#   6441,
#   2203,
#   4322,
#   5134,
#   8319,
#   3774,
#   4845,
#   5811,
#   10522,
#   4395,
#   7749],
#  [11925,
#   10355,
#   409,
#   851,
#   4845,
#   3682,
#   8562,
#   6032,
#   11385,
#   10355,
#   12917,
#   10174,
#   4845,
#   4961,
#   13531,
#   1216,
#   7],
#  [1670, 6115, 5701, 9450, 7655, 2588, 3653, 8099, 9760],
#  [6390, 2567, 2629, 10660, 1837, 9977, 2423, 6447],
#  [9661, 7890, 2203],
#  [10964, 2852, 7358, 8233, 5690],
#  [11011, 390, 4704, 9369, 12566, 6976, 11994, 499, 12764, 9144, 6655, 4707],
#  [9676, 10745, 1068, 11857, 8590, 2068, 2164, 8780, 8501, 9218, 8590, 2068],
#  [11033, 34, 2330, 12479, 13557, 13080],
#  [5344, 5137],
#  [11489, 12157],
#  [7969, 8850, 10769, 6444, 2330, 4862, 8338, 4704, 4845, 3682, 13007, 5561],
#  [4845, 12557, 1216, 6331, 6247, 1516],
#  [3795, 11868, 7057, 8458, 10083, 10083, 2874, 5676, 4845, 9592, 4074, 2442],
#  [7267,
#   9510,
#   10643,
#   2752,
#   10667,
#   4053,
#   3611,
#   3588,
#   9676,
#   1216,
#   12499,
#   4845,
#   654,
#   10355,
#   9533],
#  [9661, 2299, 11868, 9351, 3570, 6665],
#  [9676, 13626, 12426, 9661, 7467, 10789, 13627],
#  [4141, 7600, 8071, 8099, 13820, 2308, 9132, 4447, 9916, 7229, 12511],
#  [7742, 8050, 8102, 4736, 6472, 9741],
#  [7486, 13251, 11178, 122, 2881, 10545],
#  [10598,
#   288,
#   13577,
#   1403,
#   10355,
#   4286,
#   2203,
#   1616,
#   12817,
#   5102,
#   2657,
#   8784,
#   4609],
#  [7935, 36, 3215],
#  [12317, 10306, 7528, 4045, 41],
#  [5867, 11033, 9617, 8319, 12426, 9661, 4447, 3743],
#  [4434, 13169, 8501, 10474, 2003, 10636, 5192, 823, 5636, 11383, 3292],
#  [7953, 4754, 3697, 11857, 8320, 3269, 3934, 3570, 2068, 3743, 13886],
#  [13638, 6293, 110, 10360, 3564, 1837, 9294, 5260],
#  [9661,
#   1841,
#   7657,
#   1057,
#   5404,
#   13421,
#   10311,
#   1490,
#   12511,
#   3883,
#   5041,
#   5827,
#   4223,
#   6236,
#   13626],
#  [7953, 7331, 8094, 1127, 13285, 10141, 6582],
#  [10360,
#   6430,
#   13150,
#   2783,
#   10737,
#   7262,
#   851,
#   1477,
#   10355,
#   7964,
#   7651,
#   6463,
#   1541,
#   4704],
#  [10520, 7535, 3813, 816, 7332, 10520, 2588, 3546, 2429, 6570, 9896, 7, 3611],
#  [6519,
#   10355,
#   9351,
#   8550,
#   5415,
#   12865,
#   9434,
#   10323,
#   4379,
#   744,
#   6156,
#   10524,
#   1216],
#  [7953, 409, 7809, 6974, 10474, 9041],
#  [5356, 12718, 4318, 3221, 941, 4546, 3587, 4318, 3221, 2151],
#  [1736,
#   12075,
#   9855,
#   5784,
#   851,
#   9591,
#   5757,
#   7292,
#   2812,
#   8420,
#   10355,
#   11033,
#   9592,
#   6378,
#   8458,
#   851],
#  [10355, 5903, 12615, 10434, 7077, 9617, 9041],
#  [11172, 13780, 651],
#  [3732, 2525, 4845, 2901, 1452, 13037, 7607],
#  [2933, 5279, 4447],
#  [11984, 11933, 13357, 7077, 6211, 13285, 11826, 9378, 133],
#  [8099],
#  [9867, 719, 10355, 5747, 8887, 9449, 10323, 8252],
#  [10860, 8045, 11857, 1736, 7657, 3167, 2289, 5115],
#  [825, 598, 5279, 626, 1959, 2068, 11835, 3349],
#  [6211, 5004, 5261],
#  [3479, 7484, 4735, 10237],
#  [11152, 4818, 5137],
#  [13040, 8047, 4447, 3743, 13202],
#  [4045, 10524, 3249],
#  [10355, 4094, 5279, 2236, 10355, 3174, 7590, 2912, 2540],
#  [7953,
#   10355,
#   11895,
#   6507,
#   744,
#   5442,
#   8658,
#   6090,
#   9327,
#   476,
#   470,
#   5442,
#   4845,
#   11732],
#  [8167],
#  [12757,
#   6575,
#   6036,
#   9482,
#   1713,
#   4487,
#   2406,
#   7050,
#   1057,
#   8311,
#   11033,
#   10660,
#   11719],
#  [13084, 11732],
#  [3620, 5164, 5407, 1512, 11104, 9310, 10859],
#  [10520, 11984, 2821, 6950],
#  [3743, 6174, 6211],
#  [6978, 9041, 1349, 1825, 10140, 11246, 173, 1295, 4704, 4546, 7564],
#  [2703,
#   12864,
#   10524,
#   4447,
#   6783,
#   6910,
#   6247,
#   7969,
#   10988,
#   1609,
#   1403,
#   805,
#   582],
#  [533, 8996],
#  [6052,
#   6032,
#   5080,
#   5362,
#   12784,
#   8236,
#   1618,
#   4845,
#   11033,
#   11478,
#   11276,
#   4736,
#   4667,
#   5102,
#   7969,
#   5080,
#   1238,
#   5864],
#  [9617,
#   9041,
#   12564,
#   11865,
#   11719,
#   1485,
#   7714,
#   11478,
#   9041,
#   11006,
#   2507,
#   11352,
#   4982,
#   6236,
#   6569],
#  [6796, 1790, 10474, 11383, 8501, 2669],
#  [7749, 476, 6556, 9701, 9785],
#  [1883, 2117, 11172],
#  [7970, 13252, 8458, 7229, 9061, 2455, 6247, 7561, 11683, 13834],
#  [12318, 10076, 851, 6573, 1501, 13202],
#  [6623, 13835, 13384, 10992],
#  [3495, 8902, 13384, 6711, 9450, 7292],
#  [5327, 5911, 11984, 4283, 12518, 6336, 9369],
#  [5867, 2885, 10289, 3697, 3567, 470, 12028, 12168],
#  [5837, 7935, 4845, 1053, 10144, 4938, 11984, 587, 4322, 10524, 8195],
#  [3299, 10355, 9018, 9910, 545],
#  [5150, 8319, 1862, 4862, 6771, 3007],
#  [10859, 1997, 12566, 4328, 9485, 2990, 3610, 11730, 3390, 2228],
#  [3661, 8047, 851, 12305, 8664, 9806, 13146, 4557],
#  [2930, 93, 12625, 12922, 1485, 7714, 300, 13495, 6514, 13886, 10660, 12305],
#  [6462, 12566, 1670, 5115, 6666, 4667, 2220, 8099],
#  [11798, 8418, 1138, 851, 13146, 262, 1216],
#  [9676, 3661, 4322, 10729, 2023, 3222, 6623, 9524, 8585, 6925],
#  [9661, 5069, 5279, 10360, 9684],
#  [1513, 3515, 10548, 6507, 6693, 3516],
#  [7811,
#   3682,
#   1923,
#   6940,
#   9041,
#   13037,
#   7473,
#   11857,
#   122,
#   7527,
#   1923,
#   4447,
#   11048],
#  [4965, 4965, 11172, 13344, 7899, 5658],
#  [5261, 10631, 13785, 6336, 11414],
#  [6507, 1131, 5028, 2749, 1895, 875],
#  [3682, 8458, 4470, 3356],
#  [4322, 8240],
#  [3427,
#   11426,
#   3581,
#   13154,
#   13146,
#   8516,
#   10567,
#   13626,
#   409,
#   9935,
#   13886,
#   4318,
#   8099,
#   5134,
#   6404],
#  [8920, 7387],
#  [10355, 7801, 10355, 9250, 6032, 13169, 5279, 13080, 5367, 8645, 2628],
#  [569, 3682, 11361, 9652, 1924, 2657, 1449, 4817],
#  [5867, 10355, 4704, 3570, 1535, 11857, 6381, 5261, 1477],
#  [13707, 7355, 10355, 6940, 4704],
#  [7425, 4986, 3221, 10883, 4769],
#  [3174,
#   3410,
#   10520,
#   1127,
#   11857,
#   9519,
#   10474,
#   1477,
#   10355,
#   1709,
#   10558,
#   2092,
#   5283,
#   11970,
#   3174,
#   10360,
#   2343,
#   7629],
#  [7960, 4322, 6381, 470, 10360, 344, 9107],
#  [4704, 987, 3682, 4447, 5906, 6577, 11033, 480, 3575, 10747],
#  [12277, 9661, 12197, 10992, 8645],
#  [10096, 9634, 7574],
#  [8501, 4045, 4704],
#  [7742, 8677, 2382, 13820, 7472, 11330, 13292, 11276, 8458, 11902],
#  [10355,
#   9386,
#   8766,
#   2203,
#   6208,
#   11902,
#   122,
#   13252,
#   13317,
#   9661,
#   11467,
#   8099,
#   13276,
#   8700,
#   4403],
#  [1812, 9756, 13209, 12511, 6502],
#  [7707, 6092, 8047, 939],
#  [9351, 4704, 4754, 9369, 7564, 10123],
#  [10174,
#   2999,
#   779,
#   13820,
#   9848,
#   11857,
#   4602,
#   11361,
#   2309,
#   6032,
#   9023,
#   875,
#   12573,
#   3462,
#   7229],
#  [358, 4845, 13251, 12225, 4845, 13443],
#  [11172, 6894, 3942, 12976, 7655, 12234, 9041],
#  [744, 6189, 8336, 8094, 409],
#  [3697,
#   6655,
#   10299,
#   10360,
#   9636,
#   12947,
#   10520,
#   11888,
#   2395,
#   5958,
#   10355,
#   11835,
#   831,
#   1511,
#   4141,
#   10635,
#   9041,
#   4337],
#  [899, 11001, 9798, 1100, 4845, 462, 9659],
#  [972, 3581, 598, 2447, 6364, 3697],
#  [9088, 5653, 13850, 13827, 1444, 5325, 8550, 8414, 9185, 9163, 8218],
#  [8458, 7943, 6769, 5925, 6251, 4013, 13272],
#  [8809],
#  [13148, 12267, 2516],
#  [9719,
#   12421,
#   4655,
#   5751,
#   409,
#   5080,
#   11382,
#   2226,
#   3398,
#   4207,
#   5279,
#   7969,
#   12421,
#   4655,
#   589],
#  [4208, 6869, 7210, 8264, 5279, 3696, 10992],
#  [7749, 928, 10723, 3743, 6430, 10874, 11523, 8704, 4579],
#  [3682, 11857, 12615, 4845, 2345, 173, 11857, 10567, 3586],
#  [2574,
#   9041,
#   11178,
#   12932,
#   4275,
#   8071,
#   9041,
#   10355,
#   4318,
#   6507,
#   10546,
#   9450,
#   8182],
#  [3201, 5791, 1033, 12353, 6507, 4328, 10593, 3602, 9617],
#  [8458,
#   8269,
#   510,
#   9661,
#   7905,
#   11172,
#   2397,
#   2442,
#   6776,
#   10360,
#   10474,
#   1964,
#   8176],
#  [9369, 6362, 8458, 5878, 12161, 8407],
#  [7801, 10360, 11288],
#  [13306, 1127, 1403, 1403],
#  [10202, 4241, 809, 10006, 12251, 4282],
#  [7970, 4318, 4120],
#  [10643,
#   1378,
#   9654,
#   7486,
#   911,
#   4235,
#   13169,
#   10474,
#   9724,
#   951,
#   3098,
#   12511,
#   2901,
#   928],
#  [5080, 7720, 9938, 4845, 9653, 1923, 10714, 4079],
#  [4845, 5543, 7894, 7375, 11798, 3222, 10174, 510],
#  [7224,
#   13531,
#   6507,
#   9790,
#   1224,
#   11835,
#   11348,
#   13276,
#   11343,
#   10360,
#   10789,
#   12475,
#   7749,
#   6815,
#   13080,
#   10355,
#   13561,
#   10174],
#  [12864,
#   4150,
#   348,
#   9746,
#   10682,
#   4862,
#   8626,
#   8458,
#   12615,
#   11826,
#   782,
#   7224,
#   13531,
#   6189,
#   2266,
#   3580],
#  [13626, 13146, 3891, 2829, 3062, 7969, 13808, 6950, 1736, 3369, 675],
#  [4170,
#   1736,
#   13330,
#   7664,
#   2266,
#   13080,
#   9486,
#   12704,
#   1997,
#   2742,
#   4667,
#   10434,
#   1915,
#   4704,
#   4211],
#  [4395, 1399, 6378, 12363, 6348, 9405],
#  [8516, 11693, 10747, 6092],
#  [825, 6528, 4099, 4694, 3917, 8263, 11364, 8501, 6471, 2220, 11488, 6742],
#  [9355,
#   3110,
#   2063,
#   1837,
#   6013,
#   13058,
#   11857,
#   7224,
#   13531,
#   6573,
#   13197,
#   13216,
#   6373,
#   4045,
#   6032,
#   9661,
#   7905,
#   10360],
#  [3167, 5612, 4735, 10237, 6507, 9983, 6910],
#  [13315, 12697, 13037, 8362, 8809],
#  [7886, 5217, 2089, 5837, 12434, 7639, 13454, 2068],
#  [11478, 11478, 8032],
#  [3045, 6138, 10524, 3743, 13689, 2896, 11348],
#  [7953, 10355, 12626, 6533, 9724, 9041],
#  [5574, 1929, 3591, 1929, 942, 470, 1929, 2843, 1929],
#  [5837, 12657, 9041, 8782, 9935],
#  [8458, 1849, 870],
#   1600,
#   470,
#   10525,
#   2151,
#   2330,
#   11399,
#   13556,
#   4704,
#   7914],
#  [3299, 10929, 5507, 11493, 10144, 4704, 2016, 578, 12225],
#  [3495, 10912, 582, 12570, 11585, 12518, 5867, 11288, 8237, 5718, 2090, 10299],
#  [11033,
#   11033,
#   11033,
#   3299,
#   11335,
#   4350,
#   3581,
#   10074,
#   9676,
#   12718,
#   3299,
#   12285,
#   11401,
#   10345],
#  [5327],
#  [2212, 1110, 7229, 4845, 1923, 12917, 851],
#  [4664, 4395],
#  [5899, 3564, 4447, 10798, 10798],
#  [6290, 9386, 1629, 7472, 9723, 4447, 2567, 589],
#  [3796,
#   2193,
#   9592,
#   1086,
#   13557,
#   4081,
#   267,
#   8886,
#   10474,
#   9592,
#   12615,
#   2220,
#   1997,
#   9041,
#   4136],
#  [470, 667, 7914],
#  [4845, 6063, 6811],
#  [3248,
#   13814,
#   9661,
#   10417,
#   34,
#   6381,
#   13378,
#   806,
#   7387,
#   9369,
#   10417,
#   10846,
#   7860,
#   1127,
#   10762],
#  ...]

# %%
max_len = df['Word_Count'].sort_values(ascending=False).values[0] + 1

max_len
# Out:
# 27

# %%
padded_sequence = pad_sequences(sequences=sequences, maxlen=max_len, padding='post')

padded_sequence
# Out:
# array([[ 8047,  4447,  2901, ...,     0,     0,     0],
#        [10474, 12075, 10593, ...,     0,     0,     0],
#        [  533, 13820,  4986, ...,     0,     0,     0],
#        ...,
#        [ 9653, 11471,  5281, ...,     0,     0,     0],
#        [10126,  8954,  6613, ...,     0,     0,     0],
#        [ 6083,   173,  5500, ...,     0,     0,     0]])

# %% [markdown]
# #### Spliting the Data

# %%
x_train, x_test, y_train, y_test = train_test_split(padded_sequence, df['Sentiment'], test_size=0.2, random_state=42)
x_test, x_val, y_test, y_val = train_test_split(x_test, y_test, test_size=0.5, random_state=42)

print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
print(x_val.shape, y_val.shape)
# Out:
# (7962, 27) (7962,)
# (995, 27) (995,)
# (996, 27) (996,)

# %%
embedding_length = 200
e_pochs = 10
batch_size = 64

# %% [markdown]
# #### Word2Vec

# %% [markdown]
# 1. Converting word to vector

# %%
word_list = list(map(lambda x: re.findall(r'[\w]+',x), df['Cleaned_Tweets']))

word_list
# Out:
# [['want', 'go', 'home', 'bored', 'work'],
#  ['good',
#   'call',
#   'holding',
#   'take',
#   '3',
#   'cause',
#   'take',
#   '1',
#   'wa',
#   'huge',
#   'failure'],
#  ['watched', 'new', 'moon', 'trailer', 'aa', 'love'],
#  ['go', 'check'],
#  ['mammaaaaa', 'amp', 'sister'],
#  ['oh', 'ouchie', 'back', 'maybe', 'reason', 'woke'],
#  ['lol',
#   'best',
#   'friend',
#   'im',
#   'assuming',
#   'mean',
#   'snooter',
#   'great',
#   'pic',
#   'way'],
#  ['favicon', 'ripoff', 'smashing', 'magazine', 'ltgt', 'see', 'similarity'],
#  ['didnt', 'topic', 'im', 'trying', 'branch', 'amp', 'relationship', 'stuff'],
#  ['life', 'gt', 'life'],
#  ['yes'],
#  ['pervs',
#   'twitter',
#   'dont',
#   'say',
#   'oh',
#   'pervs',
#   'would',
#   'assume',
#   'freudian'],
#  ['nooo', 'im', 'loosin', 'follower', 'aweee'],
#  ['car', 'wiff', 'danny', 'going', '209'],
#  ['congratulation', 'finally'],
#  ['temporary', 'happiness'],
#  ['great', 'get', 'together', 'dgbians'],
#  ['theyre',
#   'still',
#   'young',
#   'wait',
#   'year',
#   'theyre',
#   'playing',
#   'prank',
#   'first',
#   'asleep',
#   'playing',
#   'musicgames',
#   'night'],
#  ['glad', 'two', 'day', 'five', 'straight', 'tho', 'goodbye', 'weekend'],
#  ['reading',
#   'eip',
#   'really',
#   'must',
#   'taken',
#   'alot',
#   'first',
#   'time',
#   'around'],
#  ['put',
#   'good',
#   'show',
#   'politics',
#   'show',
#   'missed',
#   'known',
#   'wa',
#   'would',
#   'watched'],
#  ['friend', 'xx'],
#  ['hum', 'happened', 'wheres', 'sun'],
#  ['scary'],
#  ['true',
#   'tiredness',
#   'worry',
#   'guess',
#   'hope',
#   'get',
#   'rest',
#   'today',
#   'keeping',
#   'optimistic',
#   'key',
#   'eight',
#   'capital'],
#  ['yay', 'hill', 'premiere', 'australia', 'tonight', 'cant', 'wait'],
#  ['finally',
#   'finished',
#   'watching',
#   'movie',
#   'quotpulsequot',
#   'know',
#   'movie',
#   'root',
#   'everyone',
#   'die',
#   'sometimes',
#   'even',
#   'doe',
#   'help'],
#  ['thanks', 'mozes', 'message'],
#  ['like', 'see', 'im', 'looking', 'im', 'walking', 'pas', 'mirrorsing'],
#  ['oh',
#   'wa',
#   'thing',
#   'didnt',
#   'wan',
#   'na',
#   'hear',
#   'penis',
#   'vagina',
#   'thing',
#   'im',
#   'sorry',
#   '3'],
#  ['happy', 'birthday', 'evee'],
#  ['well', 'shitmaybe', 'napa', 'wont', 'happen', 'weekend'],
#  ['im', 'wash', 'car', 'boring'],
#  ['lmao',
#   'girlll',
#   'swear',
#   'u',
#   'need',
#   'show',
#   'sumthin',
#   'u',
#   'keep',
#   'entertained'],
#  ['thing', 'long', 'word'],
#  ['nothing', 'tonight'],
#  ['love',
#   'banana',
#   'republictheir',
#   'perfume',
#   'classic',
#   'one',
#   'favesthanks',
#   'link'],
#  ['offically', 'work', 'today', 'ooo', 'cant', 'wait', 'big', 'brother'],
#  ['910', 'ok', 'im', 'outta', 'left', 'couple', 'cafe', 'supressos'],
#  ['yep',
#   '12quot',
#   'powerbook',
#   'wa',
#   'hallmark',
#   'portable',
#   'computing',
#   'history',
#   'dont',
#   'miss',
#   'compiling',
#   'firefox',
#   'tho'],
#  ['last', 'word'],
#  ['beer', 'im', 'jealous', 'wan', 'na'],
#  ['lovely', 'date', 'wa', 'gentleman', 'weather', 'today', 'rubbish', 'tho'],
#  ['one', 'thing', 'left', 'say', 'agrrr'],
#  ['spending', 'time', 'angela', 'leaf'],
#  ['singapore',
#   'wa',
#   'hook',
#   'last',
#   'night',
#   'forced',
#   'self',
#   'early',
#   'see',
#   'place',
#   'day',
#   'leave',
#   '11pm',
#   'tonight',
#   'enough',
#   'time'],
#  ['really', 'stiff', 'neck'],
#  ['aww', 'chick', 'hope', 'u', 'feel', 'better', 'soon'],
#  ['oneline', 'function', 'call', 'use', 'template', 'grab', 'feed'],
#  ['loving', 'good', 'weather', 'hating', 'sunburn'],
#  ['arm',
#   'leg',
#   'thigh',
#   'ankle',
#   'foot',
#   'leg',
#   'sore',
#   'yesterday',
#   'today',
#   'thats',
#   'whole',
#   'point'],
#  ['watchin', 'sex', 'city', 'madre'],
#  ['hey', 'follow'],
#  ['cant',
#   'get',
#   'damn',
#   'google',
#   'desktop',
#   'gadget',
#   'google',
#   'reader',
#   'work'],
#  ['cant', 'believe', 'missed', 'show'],
#  ['maybe', 'stop', 'lazy'],
#  ['yeah', 'think', 'thing'],
#  ['happy', 'belated', 'birthday', 'mine', 'tomorrow'],
#  ['well',
#   'night',
#   'seems',
#   'pretty',
#   'boring',
#   'comparison',
#   'stroke',
#   'youve',
#   'experienced',
#   'tonight'],
#  ['p', 'free', 'week', 'need', 'hang'],
#  ['done',
#   'marking',
#   'yippee',
#   'lil',
#   'short',
#   'break',
#   'come',
#   'end',
#   'ti',
#   'month',
#   'flu',
#   'go',
#   'away'],
#  ['hangin', 'luba', 'last', 'night', 'wa', 'pretty', 'intense'],
#  ['rock', 'n', 'roll'],
#  ['promise', 'youll', 'report'],
#  ['heard',
#   'big',
#   'loud',
#   'row',
#   'thought',
#   'maybe',
#   'jonas',
#   'brother',
#   'plane',
#   'untill',
#   'realised',
#   'wa',
#   'next',
#   'door',
#   'getting',
#   'bin'],
#  ['think', 'right', 'bought', 'new', 'cartridge', 'envelope', 'inside'],
#  ['positive', 'vibe', 'thanks', 'al', 'dat', 'juridische', 'gelul'],
#  ['chicflick', 'movie'],
#  ['got', 'playing', 'background', 'mcfly', 'arent', 'actually'],
#  ['ugh', 'suck', 'couldnt', 'play', 'wow', 'laptop', 'play', 'later', 'gah'],
#  ['pushing',
#   'daisy',
#   'reaper',
#   'sit',
#   'shut',
#   'big',
#   'bang',
#   'theory',
#   'la',
#   'season',
#   'finale',
#   'de',
#   'hero',
#   'chuck',
#   'en',
#   'eso',
#   'ocupare',
#   'mi',
#   'sabado'],
#  ['playing', 'restaurant', 'city'],
#  ['welcome', 'pleasure'],
#  ['laying', 'floaty', 'pool', 'studying', 'final'],
#  ['dont', 'know', 'im', 'making', 'right', 'decision'],
#  ['try', 'forget'],
#  ['cant', 'find'],
#  ['feel',
#   'like',
#   'need',
#   'good',
#   'company',
#   'tonight',
#   'doe',
#   'feel',
#   'like',
#   'one',
#   'around'],
#  ['workclassthen',
#   'going',
#   'look',
#   'hdmi',
#   'cable',
#   'suggestionsthere',
#   'many',
#   'chose',
#   'fromi',
#   'dont',
#   'understand'],
#  ['letting', 'creative', 'writing', 'flow', 'good', 'result', 'far'],
#  ['successfully',
#   'upgraded',
#   'macbook',
#   'hard',
#   'drive',
#   '320',
#   'gb',
#   '7200',
#   'rpm',
#   'faster',
#   'speed',
#   'actually',
#   'make',
#   'diff',
#   'quite',
#   'pleased'],
#  ['dad', 'want', 'take', 'dog', 'pound'],
#  ['waking', 'disney', 'make', 'happy'],
#  ['tell', 'whats', 'going', 'get', 'moved', 'seems', 'like', 'tireing'],
#  ['hang',
#   'build',
#   'fortress',
#   'book',
#   'box',
#   'amp',
#   'poster',
#   'tube',
#   'denver'],
#  ['aw', 'cute', 'happy', 'birthday', 'elvis'],
#  ['monday', 'morning', 'exam', 'ruined', 'sleeping', 'patten'],
#  ['daddy',
#   'wa',
#   'choosing',
#   'quoteagle',
#   'eyequot',
#   'amp',
#   'memy',
#   'lil',
#   'bro',
#   'amp',
#   'stephmother',
#   'wa',
#   'amp',
#   'steph',
#   'wa',
#   'good',
#   'mood',
#   'watching',
#   'horrible'],
#  ['ha',
#   'recently',
#   'survived',
#   'another',
#   'nosebleed',
#   'attack',
#   'suck',
#   'injury',
#   'inside',
#   'nose'],
#  ['lost', 'please', 'help', 'find', 'good', 'home'],
#  ['headache'],
#  ['food',
#   'better',
#   'people',
#   'polite',
#   'weather',
#   'nicer',
#   'buy',
#   'house',
#   '200k',
#   'le',
#   'whats',
#   'like'],
#  ['taking', 'cat', 'vet', 'today', 'get', 'spayed'],
#  ['idea', 'woke', 'cant', 'go', 'back', 'sleep', 'lol'],
#  ['aww', 'robert', 'really', 'good', 'memory', 'washington', 'square', 'park'],
#  ['thanks'],
#  ['wow',
#   'reading',
#   'tweet',
#   'water',
#   'fast',
#   'youre',
#   'going',
#   'peeing',
#   'time'],
#  ['sleepy',
#   'whole',
#   'morning',
#   'ngayon',
#   'lang',
#   'nagkaenergy',
#   'move',
#   'around'],
#  ['good', 'result', 'ireland', 'happy', 'enough'],
#  ['beautiful',
#   'gourmet',
#   'candle',
#   'clean',
#   'burning',
#   '90',
#   'soot',
#   'free',
#   'richly',
#   'scented',
#   'love'],
#  ['shame',
#   'hand',
#   'ear',
#   'amp',
#   'eye',
#   'thats',
#   'possible',
#   'im',
#   'listening',
#   'looking',
#   'lol',
#   'going',
#   'tough',
#   '39',
#   'day'],
#  ['get',
#   'stung',
#   'bee',
#   'bug',
#   'south',
#   'horrible',
#   'hope',
#   'werent',
#   'attacked',
#   'badly'],
#  ['christ',
#   'last',
#   'night',
#   'baby',
#   'went',
#   'mental',
#   'sounded',
#   'like',
#   'fog',
#   'horn',
#   '2',
#   'morn',
#   'little',
#   'shit',
#   'love'],
#  ['wa', 'bus', 'morning', '649', 'good'],
#  ['awww', 'thats', 'pitiful', 'poor', 'lil', 'baby'],
#  ['eat',
#   '5',
#   'time',
#   'day',
#   'go',
#   'bathroom',
#   'weight',
#   'isnt',
#   'increasing',
#   'wondering',
#   'food',
#   'going'],
#  ['heeeyyyyy', 'need', 'ur', 'numberlost', 'phone'],
#  ['lovely', 'pbampj', 'ready', 'get', 'orygun'],
#  ['wa',
#   'good',
#   'working',
#   'wii',
#   'fit',
#   'broke',
#   'left',
#   'arm',
#   'set',
#   'back'],
#  ['wonder', 'twin', 'power', 'twin', 'deactivated', 'power', 'ish', 'sad'],
#  ['relate', 'grace', 'especially', 'relational', 'reality', 'coffee'],
#  ['im',
#   'gon',
#   'na',
#   'make',
#   'extra',
#   'money',
#   'working',
#   'part',
#   'time',
#   'gon',
#   'na',
#   'buy',
#   'watch'],
#  ['ugh', 'weekend', 'go'],
#  ['fun', 'like', 'winter', 'middle', 'summer', 'sorta', 'lol'],
#  ['reason', 'dont', 'give', '3', 'year', 'old', 'chocolate', 'jake', 'nephew'],
#  ['watched',
#   'footage',
#   'epic',
#   'sleepover',
#   'xd',
#   'funn',
#   'timezz',
#   'lt3333333'],
#  ['good',
#   'people',
#   'like',
#   'arent',
#   'scared',
#   'say',
#   'real',
#   'tweet',
#   'transparency',
#   'shown',
#   'real',
#   'cheer'],
#  ['wish', 'wa', 'momma', 'chopard', 'old', 'car', 'race'],
#  ['loooool',
#   'ati',
#   'always',
#   'excited',
#   'im',
#   'better',
#   'actor',
#   'thought',
#   'apparently',
#   'im',
#   'alright',
#   'hopped',
#   'ice',
#   'coffee',
#   'yum'],
#  ['tweet', 'wa', 'included', 'longest', 'poem', 'world'],
#  ['say', 'work', 'till', 'morninggood', 'luck'],
#  ['last', 'night', 'passed', 'way', 'goat', 'feather'],
#  ['body', 'call', 'talk'],
#  ['aww', 'good'],
#  ['world', 'would', 'blow'],
#  ['haiyaaai',
#   'wish',
#   'sleep',
#   'nowi',
#   'tried',
#   'stillerm',
#   'gud',
#   'part',
#   'isim',
#   'longer',
#   'workinand',
#   'start',
#   'job',
#   'hunt'],
#  ['third', 'familyforce5'],
#  ['yep', 'better', 'soon'],
#  ['standing',
#   'line',
#   'kawasaki',
#   'demo',
#   'sign',
#   'im',
#   'far',
#   'enough',
#   'back',
#   'might',
#   'miss',
#   'bike',
#   'want',
#   'ride'],
#  ['wouldnt', 'pay', 'follower'],
#  ['rained', 'market', 'closed', 'fml', 'tfv'],
#  ['hurt', 'feeling'],
#  ['im', 'jealous', 'mama', 'left', 'yesterdaysounds', 'like', 'weekend'],
#  ['nice', 'gt', '3wordsduringsex', 'central', 'know', 'hongkong'],
#  ['cleaning', 'room'],
#  ['ill', 'post', 'twitter', 'quotlilygreenxxx', 'ripquot'],
#  ['home',
#   'sweet',
#   'home',
#   'quotits',
#   'hard',
#   'day',
#   'night',
#   'ill',
#   'sleeping',
#   'like',
#   'logquot'],
#  ['mean', 'whats', 'song', 'demet'],
#  ['revising', 'sod'],
#  ['yeah', 'stockholm', 'great', 'music', 'f12', 'tonight'],
#  ['lost'],
#  ['looked',
#   'getting',
#   'tix',
#   'see',
#   'pen',
#   'play',
#   'carolinabut',
#   'way',
#   'toooo',
#   'pricey',
#   'u',
#   '4',
#   'hour',
#   'drive',
#   'though'],
#  ['cant', 'wait', 'see', 'video', 'danny', 'sure', 'going', 'great'],
#  ['said', 'leave', 'soon'],
#  ['good',
#   'old',
#   'integer',
#   'overflow',
#   'might',
#   'check',
#   'properlyï½',
#   'felt',
#   'bit',
#   'like',
#   'since',
#   'coming',
#   'home',
#   'afternoon'],
#  ['ahhaj',
#   'tank',
#   'go',
#   'sleep',
#   'see',
#   'later',
#   'want',
#   'tomorrow',
#   'goodbye',
#   'girl'],
#  ['wish', 'wa', 'pastazios', 'new', 'york', 'pizza', 'fort', 'worth'],
#  ['cool', 'wish', 'video'],
#  ['meeting',
#   'wa',
#   'fate',
#   'becoming',
#   'friend',
#   'wa',
#   'choice',
#   'falling',
#   'love',
#   'control'],
#  ['last', 'day', 'high', 'school', 'ever'],
#  ['thanks',
#   'im',
#   'boat',
#   'trying',
#   'finish',
#   'new',
#   'collectionbut',
#   'probably',
#   'start',
#   'new',
#   'book'],
#  ['cheeba', 'super', 'sick', 'shes', 'hospital', 'pray', 'get', 'well'],
#  ['family',
#   'time',
#   'good',
#   'sometimes',
#   'everyone',
#   'acting',
#   'fake',
#   'hmmm',
#   'ditching',
#   'rocking',
#   'uplifter',
#   '311',
#   'make',
#   'happy'],
#  ['quite', 'opposite', 'im', 'sure', 'wa', 'part', 'plan', 'masterchef'],
#  ['back',
#   'lunch',
#   'stuffed',
#   'didnt',
#   'eat',
#   'much',
#   'didnt',
#   'feel',
#   'like',
#   'eating',
#   'lot',
#   'im',
#   'drinking',
#   'iced',
#   'tea'],
#  ['tan',
#   'line',
#   'one',
#   'side',
#   'oh',
#   'well',
#   'guess',
#   'ill',
#   'tan',
#   'somemore',
#   'grad'],
#  ['sound', 'good', 'sure', 'pick', 'brain', 'thing', 'virtulisation'],
#  ['morning', 'ldn', 'time', 'tomorrow', 'ill', 'landing', 't5'],
#  ['culdesacs', 'greatest', 'threat', 'world'],
#  ['love', 'quotjust', 'showerquot', 'feeling'],
#  ['sweeeeet', 'jack', 'whitehall', 'swoooon', 'xxx'],
#  ['dont', 'worry', 'wont', 'hate', 'spoiler', 'much'],
#  ['youre', 'hour', 'early', 'thank'],
#  ['morning', 'time', 'put', 'clothes', 'go', 'work'],
#  ['awkward', 'family', 'photo', 'funny'],
#  ['yeah',
#   'food',
#   'fatty',
#   'unfortunately',
#   'top',
#   'shelf',
#   'vodka',
#   'organic',
#   'nut',
#   'really',
#   'put',
#   'dent',
#   'one',
#   'wallet'],
#  ['took',
#   'artie',
#   'dog',
#   'park',
#   'amp',
#   'realized',
#   'peeing',
#   'bit',
#   'blood',
#   'exercise',
#   'wonder',
#   'stamina'],
#  ['burnt', 'roast', 'carrot', 'hitting', 'blue', 'antidote', 'superbad'],
#  ['officially', 'given', 'studying', 'ill', 'cram', 'exam', 'tomorrow'],
#  ['hey',
#   'everyone',
#   'follow',
#   'ha',
#   'crazy',
#   'amazing',
#   'singing',
#   'voice',
#   'dont',
#   'know',
#   'charice',
#   'soon'],
#  ['bah',
#   'starter',
#   'car',
#   'died',
#   'today',
#   'dont',
#   'know',
#   'much',
#   'long',
#   'take',
#   'get',
#   'fixed',
#   'get',
#   'back',
#   'car'],
#  ['wa', 'really', 'good', 'see', 'anyway'],
#  ['reading',
#   'css3',
#   'box',
#   'cooky',
#   'sits',
#   'front',
#   'im',
#   'resisting',
#   'temptation'],
#  ['ive',
#   'added',
#   'eleventh',
#   'commandmenthonor',
#   'thy',
#   'ear',
#   'soul',
#   'lteveryone',
#   'follow',
#   'part',
#   'sacred',
#   'law'],
#  ['chris',
#   'bringing',
#   'another',
#   'work',
#   'shirt',
#   'coz',
#   'shirt',
#   'dirty',
#   'last',
#   'night',
#   'got',
#   'ta',
#   'love',
#   'friend'],
#  ['hello',
#   'guy',
#   'im',
#   'trouble',
#   'twitter',
#   'moment',
#   'wont',
#   'let',
#   'chage',
#   'backgroud',
#   'xx',
#   'demmi'],
#  ['votemcfly', 'pas', 'x'],
#  ['thanks'],
#  ['missed',
#   'begining',
#   'flawless',
#   'saw',
#   'wa',
#   'awesome',
#   'aiden',
#   'better',
#   'goerge',
#   'sampson',
#   'least',
#   'made',
#   'new',
#   'dance',
#   'final'],
#  ['friend', 'couldnt', 'make'],
#  ['bah',
#   'concentrated',
#   'effort',
#   'foe',
#   'lyxanda',
#   'esmoves',
#   'killed',
#   'spymaster'],
#  ['consider',
#   'much',
#   'luck',
#   'early',
#   'bird',
#   'bad',
#   'luck',
#   'early',
#   'worm',
#   'poor',
#   'worm'],
#  ['tired', 'happy', 'mussnï½t', 'go', 'school'],
#  ['good',
#   'grief',
#   'well',
#   'dont',
#   'let',
#   'go',
#   'help',
#   'support',
#   'group',
#   'college',
#   'economy'],
#  ['make', 'contest', 'u', 'want'],
#  ['football',
#   'hooliganism',
#   'youre',
#   'right',
#   'poor',
#   'copper',
#   'deal',
#   'idiocy'],
#  ['light'],
#  ['draw', 'tellos', 'commission', 'im', 'realizing', 'much', 'miss', 'series'],
#  ['calling', 'night', 'waking', 'early', 'tomorrow'],
#  ['finally',
#   'im',
#   'back',
#   'manila',
#   'thank',
#   'god',
#   'safe',
#   'sound',
#   'trip',
#   'shalom'],
#  ['hand',
#   'made',
#   'manufactored',
#   'italyravishingwhy',
#   'eff',
#   'heel',
#   'break',
#   '4',
#   'wear',
#   'im',
#   'irkedthose',
#   'shoe',
#   'irreplaceable'],
#  ['hey',
#   'never',
#   'got',
#   'back',
#   'dont',
#   'know',
#   'answer',
#   'erdrich',
#   'play',
#   'daily',
#   'people',
#   'would',
#   'talk'],
#  ['subject',
#   'frosty',
#   'beer',
#   'bloody',
#   'fridge',
#   'ha',
#   'conked',
#   'beer',
#   'warm'],
#  ['management', 'myanmar', 'word', 'need', 'approve', '20', 'word'],
#  ['none', 'lit', 'right', 'meant'],
#  ['lakers',
#   'parade',
#   'absolutly',
#   'destroying',
#   'commute',
#   'booooooooo',
#   'lakers'],
#  ['nervous',
#   'jv',
#   'bball',
#   'reject',
#   'quoth',
#   'quotkeep',
#   'truckingquot',
#   'lt',
#   'haha',
#   'funny',
#   'marlissa',
#   'accidentally',
#   'quoted'],
#  ['cant', 'im', 'bummed'],
#  ['work',
#   'til',
#   '10',
#   'home',
#   'nap',
#   'watching',
#   'big',
#   'bang',
#   'theory',
#   'night'],
#  ['thanks',
#   'asking',
#   'brandon',
#   'lt3',
#   'think',
#   'cutest',
#   'nick',
#   'love',
#   'equally'],
#  ['quotlocked',
#   'inquot',
#   'stay',
#   'home',
#   'saturday',
#   'co',
#   'mom',
#   'vvvvvv',
#   'selfish',
#   'overexpenditure',
#   'yest',
#   'urgh'],
#  ['good', 'song'],
#  ['cheer',
#   'man',
#   'yeah',
#   'im',
#   'still',
#   'call',
#   'weather',
#   'new',
#   'brighton',
#   'may',
#   'well',
#   'something'],
#  ['easy',
#   'carbs',
#   'baby',
#   'wont',
#   'grow',
#   'big',
#   'youll',
#   'hard',
#   'time',
#   'pushing',
#   'cant',
#   'wait',
#   'lil',
#   'one'],
#  ['danmm', 'kill', 'loll', 'good', 'one'],
#  ['could', 'record', 'program', 'sorry', 'friend', 'love'],
#  ['oh',
#   'yeah',
#   'guess',
#   'could',
#   'say',
#   'particularly',
#   'shy',
#   'met',
#   'someone',
#   'person',
#   'donï½t',
#   'know',
#   'u'],
#  ['suck', 'choose', 'work', 'ridiculously', 'early', 'hour', 'lol'],
#  ['im', 'sorry', 'love', 'gosh', 'know', 'never', 'fun', 'im', 'love'],
#  ['love', 'summer', 'family', 'guy', 'make', 'laughy'],
#  ['better', 'realize', 'thing', 'thanks', 'mexican'],
#  ['boinc',
#   'ðñðñññððð',
#   'ðº',
#   'ñðð¼ñðññðð',
#   'ð½ðµð¹ñð¾ð½ð½ð¾ð¹',
#   'ñðµñð',
#   'ððñ',
#   'ñðºñððµñðð¼ðµð½ñð',
#   'ðð¾',
#   'ñð¾ðððð½ðñ',
#   'ðð',
#   'future'],
#  ['sleepy',
#   'looking',
#   'forward',
#   'nice',
#   'slow',
#   'day',
#   'studying',
#   'chocolate',
#   'chai',
#   'house',
#   'cleaning',
#   'possibly',
#   'pjs',
#   'day'],
#  ['start',
#   'taking',
#   'class',
#   'sikander',
#   'younger',
#   'brother',
#   'tackle',
#   'pro',
#   'thing'],
#  ['jordy', 'told', 'tweet', 'take', 'long', 'text', 'back'],
#  ['tiiiired',
#   'got',
#   'back',
#   '8am',
#   'final',
#   'sleeping',
#   'little',
#   'heading',
#   'work'],
#  ['oh', 'see', 'anna', 'allowed', 'buy', 'stuffed', 'eeyore', 'im'],
#  ['grateful',
#   'positive',
#   'sentiment',
#   'new',
#   'medium',
#   'im',
#   'sure',
#   'thank',
#   'best',
#   'inspire'],
#  ['let', 'get', 'business'],
#  ['back',
#   'fire',
#   'hell',
#   'maybe',
#   'ill',
#   'try',
#   'new',
#   'bathing',
#   'suit',
#   'get',
#   'jealous',
#   'everyone',
#   'continuing',
#   'jones',
#   'beach'],
#  ['wa', '2', 'half', 'hour', 'late', 'bed', 'good', 'night', 'love'],
#  ['time', 'bed', 'lvl', '12', 'rogue'],
#  ['really',
#   'dont',
#   'know',
#   'time',
#   'day',
#   'make',
#   'wan',
#   'na',
#   'come',
#   'twitter'],
#  ['nice',
#   'amp',
#   'sunny',
#   'outside',
#   'windy',
#   'uuhu',
#   'campus',
#   'always',
#   'windy'],
#  ['quite', 'pleased', 'way', 'week', 'kicking', 'may', 'trend', 'continue'],
#  ['ha', 'post', 'office', 'expect', 'snap', '3', '5', 'day'],
#  ['rain', 'rain', 'rain', '80', 'degree', 'sunshine'],
#  ['officially', 'done', 'english', '103', 'class'],
#  ['awww', 'poor', 'holly'],
#  ['dont', 'miss', 'much', 'home'],
#  ['good',
#   'feel',
#   'free',
#   'jab',
#   'away',
#   'thats',
#   'get',
#   'careful',
#   'tho',
#   'wft',
#   'could',
#   'frakin',
#   'trash'],
#  ['miss', 'facebook'],
#  ['thats', 'ok', 'ive', 'got', 'lot', 'english', 'homework', 'anyway'],
#  ['awh', 'thats', 'cute'],
#  ['would',
#   'take',
#   'youngest',
#   'dr',
#   'nh',
#   'walk',
#   'never',
#   'mess',
#   'high',
#   'temp',
#   'little',
#   'one'],
#  ['hangover', 'bitch'],
#  ['twitter', 'lame', 'duck', 'block', 'strange', 'follower'],
#  ['temple', 'awesome', 'people'],
#  ['morning', 'thanks', 'becoming', 'fan'],
#  ['waaaaaasssss', 'och', 'nein', 'traurig'],
#  ['omg', 'kitten', 'asleep', 'wow', 'bed', '830', 'whatever', 'mom', 'thank'],
#  ['board', 'n', 'want', '2', 'wa', 'lol'],
#  ['singing', 'along', 'queen', 'sun', 'good', 'time'],
#  ['link',
#   'wa',
#   'joining',
#   'google',
#   'friend',
#   'connect',
#   'join',
#   'group',
#   'directly',
#   'websitethanks'],
#  ['wish', 'could', 'come', 'meet', 'guy'],
#  ['rain', 'ruined', 'day'],
#  ['eughh', 'need', 'new', 'clothes'],
#  ['ive',
#   'thought',
#   'saw',
#   'natalie',
#   'portman',
#   'v',
#   'vendetta',
#   'amp',
#   'realized',
#   'cld',
#   'nvr',
#   'look',
#   'awesome',
#   'bald',
#   'salon'],
#  ['would',
#   'love',
#   'home',
#   'cooked',
#   'meal',
#   'right',
#   'papa',
#   'livigne',
#   'hang',
#   'pool',
#   'w',
#   'kar',
#   'kar',
#   'jess',
#   'thing'],
#  ['driving', 'grad', 'night', 'jordan', 'following'],
#  ['flight',
#   'san',
#   'franciscobut',
#   'stuck',
#   'middle',
#   'seat',
#   'long',
#   'flight'],
#  ['gettin', 'shit', 'packed', 'amp', 'together', 'weekenddd'],
#  ['isnt', 'super', 'nice', 'wasnt', 'sure', 'video', 'would', 'play'],
#  ['iranelection', 'blocked', 'iran'],
#  ['also', 'anyone', 'wa', 'paying', 'attention', 'yes', 'quit', 'smoking'],
#  ['ate',
#   'sausage',
#   'egg',
#   'im',
#   'happy',
#   'waiting',
#   'till',
#   '12',
#   'little',
#   'bros',
#   'game',
#   'start',
#   'love',
#   'watch',
#   'play'],
#  ['getting',
#   'ready',
#   'another',
#   'day',
#   'live',
#   'laugh',
#   'love',
#   'finally',
#   'got',
#   'weekend',
#   'fiasco'],
#  ['kkkkkkkkkkkkk',
#   'thats',
#   'fact',
#   'baby',
#   'thats',
#   'fact',
#   'tell',
#   'make',
#   'viado',
#   'twitter'],
#  ['still', 'havent', 'done', 'homework', 'damn', 'feel', 'lazy', 'today'],
#  ['gon', 'na', 'go', 'get', 'ready', 'cousin', 'bday', 'celeb'],
#  ['quotback', 'dat', 'full', 'servicequot'],
#  ['skype',
#   'dumb',
#   'head',
#   'lt3',
#   'miss',
#   '3',
#   'week',
#   'ill',
#   'irl',
#   'im',
#   'gon',
#   'na',
#   'hug',
#   'crush'],
#  ['sound', 'nice'],
#  ['taking', 'break', 'magazine'],
#  ['bad', 'feeling', 'cavs', 'wont', 'win', 'tonite'],
#  ['lol', 'well', 'gtg', 'guy', 'l8r', 'cya', 'school', 'peep'],
#  ['lt3', 'get', 'lt3', 'shape', 'latte'],
#  ['youre', 'like', '4', 'people', 'unfollowed', 'since', 'last', 'night'],
#  ['oh', 'werent', 'allergy', 'cold'],
#  ['fault',
#   'anyway',
#   'think',
#   'theyre',
#   'coming',
#   'around',
#   'idea',
#   'slowly',
#   'ill',
#   'get',
#   'done',
#   'eventually'],
#  ['wait', 'tour', 'december', 'best', '21st', 'birthday', 'present', 'ever'],
#  ['iplayer', 'work', 'uk', 'least', 'video'],
#  ['happy', '10000th', 'follower', 'via', 'wow', 'wa', 'lol'],
#  ['feeling', 'bit', 'tired'],
#  ['piece', 'mango', 'tart', 'cova'],
#  ['going', 'insanely', 'drunken', 'weekend', 'booyah'],
#  ['yo', 'boiiiii', 'follow', 'u'],
#  ['near', 'commute', 'im', 'amazed', 'many', 'event', 'widespread'],
#  ['mac', 'mini', 'wish', 'buy', 'mac'],
#  ['shut', 'biatch', 'poppy', 'moore', 'said'],
#  ['aw', 'shouldnt', 'moved', 'time', 'try', 'pop', 'thank'],
#  ['thats', 'beautiful', 'si'],
#  ['thanks', 'stevewere', 'still', 'new', 'twitter', 'thing'],
#  ['im',
#   'reading',
#   'twitter',
#   'fun',
#   'shes',
#   'interesting',
#   'watching',
#   'ncis'],
#  ['blown', 'hurt', 'sooooooo', 'bad'],
#  ['im',
#   'cummin',
#   '2',
#   'take',
#   'ovum',
#   'studio',
#   '2day',
#   'waitin',
#   '4',
#   'brady',
#   'come',
#   '4',
#   'like',
#   'eva'],
#  ['fundraise',
#   'cancer',
#   'research',
#   'ukit',
#   'mostly',
#   'think',
#   'ha',
#   'random',
#   'question',
#   'though',
#   'fun'],
#  ['hey', 'hows'],
#  ['go', 'work', 'today'],
#  ['spendingg', 'time', 'ness'],
#  ['id',
#   'wash',
#   'using',
#   'lestoil',
#   'detergent',
#   'youll',
#   'wash',
#   'time',
#   'work',
#   'get',
#   'smell'],
#  ['omg',
#   'realized',
#   'year',
#   'ago',
#   'today',
#   'georgia',
#   'wish',
#   'could',
#   'go',
#   'bak',
#   '2',
#   'day',
#   'georgia',
#   'period'],
#  ['hi',
#   'mattim',
#   'bcliving',
#   'sydney',
#   'au',
#   '65',
#   'yr',
#   'listening',
#   'ur',
#   'song',
#   'wanted',
#   'say',
#   'hi',
#   'love',
#   'ur',
#   'work',
#   'miss'],
#  ['planing', 'blogg', '10', 'mad', 'vid', 'got', 'muted'],
#  ['smh', 'pic', 'fer', 'heddur'],
#  ['thought',
#   'king',
#   'writes',
#   'horror',
#   'quothorrorquot',
#   'come',
#   'mind',
#   'quotreadquot',
#   'new',
#   'book',
#   'turn',
#   'page'],
#  ['think', 'flunked', 'statistic', 'practical', 'test'],
#  ['ill', 'night', 'homework'],
#  ['way', 'bak', '4rm', 'troy', 'bar', 'wasnt', 'impressed'],
#  ['pretty',
#   'good',
#   'time',
#   'trip',
#   'beginning',
#   'ending',
#   'best',
#   'come',
#   'home'],
#  ['love',
#   'watching',
#   'classic',
#   'film',
#   'tonites',
#   'good',
#   'old',
#   'american',
#   'classic'],
#  ['never',
#   'get',
#   'sleepin',
#   'guess',
#   'sunday',
#   'dont',
#   'mind',
#   'working',
#   'saturday'],
#  ['dropping', 'mum', 'station', 'ill', 'miss', 'u', 'mum'],
#  ['bus', 'stop', 'yay', 'nice'],
#  ['guided', 'tour', 'tower', 'london'],
#  ['cant',
#   'w8',
#   'get',
#   'havent',
#   'seen',
#   'store',
#   'tho',
#   'got',
#   'ta',
#   'get',
#   'online'],
#  ['call',
#   'summery',
#   'weather',
#   '23',
#   'degree',
#   'sun',
#   'beating',
#   'shame',
#   'kid',
#   'missing',
#   'bunking'],
#  ['yes', 'air', 'conditioning', 'ha'],
#  ['need',
#   'somehow',
#   '8',
#   'aai',
#   'jesus',
#   'acho',
#   'q',
#   'estou',
#   'tendo',
#   'recaidas'],
#  ['life', 'boring', 'day', 'skool', 'mondaii'],
#  ['ye', 'lol', 'wa', 'tv', 'series', 'film'],
#  ['never', 'get', 'tired', 'seeing', 'matahorn', 'freeway'],
#  ['great',
#   'day',
#   'time',
#   'family',
#   'amazing',
#   'voice',
#   'studio',
#   'party',
#   'prof',
#   'home',
#   'finance',
#   'study',
#   'date'],
#  ['dad',
#   'rock',
#   'supreme',
#   'played',
#   'hide',
#   'seek',
#   'joshua',
#   'would',
#   'excitedly',
#   'lift',
#   'sheetover',
#   'head',
#   'cool'],
#  ['man', 'short', 'nite', 'lol', 'good', 'morn'],
#  ['early'],
#  ['im',
#   'glad',
#   'britney',
#   'isnt',
#   'crazy',
#   'anymore',
#   'wa',
#   'one',
#   'hell',
#   'show',
#   'im',
#   'sad',
#   'next',
#   'upap',
#   'cook',
#   'county'],
#  ['want',
#   'husband',
#   'come',
#   'home',
#   'parent',
#   'coming',
#   'tonight',
#   'help',
#   'u',
#   'move',
#   'since',
#   'im',
#   'useless',
#   'thanks',
#   'mom',
#   'dad'],
#  ['got',
#   'pushed',
#   'poolit',
#   'felt',
#   'good',
#   'although',
#   'wouldnt',
#   'give',
#   'back',
#   'flip',
#   'flop',
#   'lol',
#   'still',
#   'love',
#   'lt3tylerlt3'],
#  ['snozberries',
#   'taste',
#   'like',
#   'snozberries',
#   '711',
#   'ha',
#   'got',
#   'slurpee'],
#  ['happened',
#   'pas',
#   'wind',
#   'right',
#   'car',
#   'horn',
#   'went',
#   'outside',
#   'honesttogod',
#   'thought',
#   'begun',
#   'emitting',
#   'cartoon',
#   'noise',
#   'mba',
#   '2',
#   'week'],
#  ['im', 'hella', 'mad', 'lol', 'xpectd', 'dat', '4rm', 'curry', 'hi'],
#  ['hi', 'new', 'blog'],
#  ['started',
#   'learning',
#   'aber',
#   'ich',
#   'bin',
#   'sehr',
#   'beschãftigt',
#   'schoolwork',
#   'cant',
#   'focus',
#   'much'],
#  ['busy', 'week', 'tiring'],
#  ['true', 'gift', 'encouragement', 'thank'],
#  ['yeah', 'taking', 'makeup', 'day', 'miss', 'fail', 'class'],
#  ['good',
#   'morningi',
#   'woke',
#   'boo',
#   'leavin',
#   'wat',
#   'im',
#   'goin',
#   'like',
#   '4',
#   'day',
#   'im',
#   'miss',
#   'already'],
#  ['miss', 'u'],
#  ['link', 'isnt', 'working'],
#  ['nooo',
#   'idea',
#   'suckful',
#   'right',
#   'would',
#   'short',
#   'tomorrow',
#   'public',
#   'presentation'],
#  ['hey', 'lewis', 'tibb', 'following', 'xd', 'nice', 'day'],
#  ['haha', 'ur', 'funny', 'thanks', 'try'],
#  ['ha',
#   '4hrs',
#   'til',
#   'get',
#   '2',
#   'hangout',
#   'yay',
#   'cant',
#   'wait',
#   'miss',
#   'ya'],
#  ['2', 'previous', 'sweet', 'kaguya', 'movie', 'btw'],
#  ['good', 'morning', 'fan'],
#  ['past',
#   '30',
#   'hour',
#   'couldnt',
#   'better',
#   'praise',
#   'god',
#   'many',
#   'blessing',
#   'love',
#   'always'],
#  ['long',
#   'work',
#   'day',
#   '2',
#   'come',
#   'home',
#   '2',
#   'car',
#   'hit',
#   'againmaybe',
#   '2morrow',
#   'better',
#   'day',
#   '2',
#   'get',
#   'ready',
#   '4',
#   'bednight'],
#  ['really', 'guess', 'dont', 'hate', 'english', 'research', 'paper'],
#  ['jessie',
#   'going',
#   'sleep',
#   'babe',
#   'catch',
#   'u',
#   'tomorrow',
#   'hug',
#   'good',
#   'nite'],
#  ['signing', 'plane', 'taking', 'soon'],
#  ['guess',
#   'youve',
#   'copied',
#   'earlier',
#   'link',
#   'time',
#   'future',
#   'twitter',
#   'one',
#   '25',
#   'medium',
#   'ppl'],
#  ['never',
#   'ha',
#   '2pm',
#   'finish',
#   'looked',
#   'enjoyable',
#   'pity',
#   'im',
#   'teetotal',
#   'another',
#   'week'],
#  ['way', 'really', 'cant', 'stand', 'suppose'],
#  ['emilia',
#   'bedilia',
#   'left',
#   'go',
#   'airport',
#   'im',
#   'alone',
#   'work',
#   'think',
#   'ill',
#   'blast',
#   'tune',
#   'goodnight',
#   'fellow',
#   'tweeter'],
#  ['longsleeve', 'ha', 'purple', 'runic', 'script', 'doe', 'count'],
#  ['last', 'lunch', 'sydney'],
#  ['havent', 'slept', 'one', 'bit', 'sore', 'throat', 'achy', 'cough', 'fever'],
#  ['yeah',
#   'im',
#   'liking',
#   'lmao',
#   'okneed',
#   'get',
#   'twitter',
#   'really',
#   'get',
#   'trouble',
#   'bored',
#   'amp',
#   'idle',
#   'time',
#   'beuno'],
#  ['good', 'monday', 'monday', 'cant', 'expect', 'much', 'angie'],
#  ['naku', 'waterloo', 'ko', 'ang', 'math', 'cant', 'help'],
#  ['im', '22', 'whyle', '23'],
#  ['escaping', 'heartache'],
#  ['real',
#   'wa',
#   'alone',
#   'miley',
#   'cyrus',
#   'would',
#   'epic',
#   'collaboration',
#   'id',
#   'dump',
#   'big',
#   'bro'],
#  ['pray'],
#  ['fffffuuuuu', 'acabei', 'de', 'ver', 'imagem', 'da', 'mione', 'ruined'],
#  ['14',
#   'run',
#   'inning',
#   'going',
#   'get',
#   'done',
#   'curse',
#   'new',
#   'stadium',
#   'yank',
#   'almost',
#   'deserve',
#   'quothouse',
#   'george',
#   'builtquot',
#   'sigh'],
#  ['going', 'outsidemaybe', 'ill', 'work', 'tan'],
#  ['aaaaaaaw', 'enjoyyyyyyyy', 'cute', 'xoxo'],
#  ['doesnt', 'take', 'run'],
#  ['need',
#   'improved',
#   'lightzone',
#   'speed',
#   'athlon64',
#   '4gb',
#   'ram',
#   'lz',
#   'slow'],
#  ['welcome', 'explore', 'enjoy'],
#  ['aiming', 'least', 'another', '2', 'holiday', 'year'],
#  ['sent', 'amp', 'home', 'something'],
#  ['thanks',
#   'saw',
#   '12',
#   'name',
#   'listno',
#   'one',
#   'know',
#   'directlyfriends',
#   'friend',
#   'though'],
#  ['right', 'say', 'dint', 'mment', 'upset', 'btw'],
#  ['yep', 'first', 'get', 'tap', 'dont', 'even', 'carry'],
#  ['wan',
#   'na',
#   'take',
#   'birthday',
#   'right',
#   'nowdo',
#   'right',
#   'spoil',
#   'night'],
#  ['right', 'stay', 'warm'],
#  ['much', 'much', 'love'],
#  ['noand', 'dont', 'like', 'vocal', 'song', 'either'],
#  ['really', 'ever', 'saw', 'tornado', 'maybe'],
#  ['apparently',
#   'theyve',
#   'found',
#   'body',
#   'floating',
#   'near',
#   'brazil',
#   'airfrance',
#   'flight',
#   'scary'],
#  ['way', 'teeside', 'park', 'new', 'album'],
#  ['im', 'alone', 'house', 'noisy', 'dog'],
#  ['saw', 'wolverine', 'youre', 'amazing'],
#  ['yeah', 'wondered', 'u', 'caught'],
#  ['cant', 'catch', 'zzzzs'],
#  ['hey', 'jared', 'sorry', 'tummy', 'upset'],
#  ['doe',
#   'mean',
#   'call',
#   'mummy',
#   'talking',
#   'cat',
#   'randomly',
#   'call',
#   'self',
#   'mummy',
#   'cat',
#   'occasion'],
#  ['going', 'see', 'the3', 'golden', 'gate', 'bridge', 'sunset'],
#  ['wa', 'wondering', 'u', 'gon', 'na', 'get', 'twitter', 'friend', 'myspace'],
#  ['agh',
#   'fattest',
#   'headache',
#   'ever',
#   'cant',
#   'pilate',
#   'amp',
#   'jog',
#   'like',
#   'ughhh'],
#  ['still', 'bed', 'amp', 'havent', 'ate'],
#  ['fun', 'day', 'wiff', 'callie', 'time', 'get', 'study'],
#  ['bahaha',
#   'nice',
#   'tbh',
#   'time',
#   'think',
#   'mcfly',
#   'realize',
#   'actually',
#   'like',
#   'different',
#   'band',
#   'haha',
#   'gosh',
#   'miss',
#   'xxx'],
#  ['haha', 'thanks', 'bunch', 'joshberry', 'fun', 'enjoy', 'day'],
#  ['waking',
#   'stomach',
#   'killing',
#   'always',
#   'tired',
#   'anxious',
#   'every',
#   'single',
#   'morning'],
#  ['feel', 'ya', 'suck', 'cant', 'day'],
#  ['great',
#   'workout',
#   'im',
#   'waiting',
#   'mister',
#   'hayes',
#   'get',
#   'look',
#   'like',
#   'ill',
#   'b',
#   'spending',
#   'remainder',
#   'day',
#   'w'],
#  ['news',
#   'junkie',
#   'thats',
#   'iam',
#   'looking',
#   'news',
#   'website',
#   'amp',
#   'also',
#   'tweetering',
#   'time'],
#  ['think', 'live', 'one'],
#  ['miss'],
#  ['know', 'lovely', 'day'],
#  ['watching',
#   'girlfriend',
#   'run',
#   'indy',
#   'half',
#   'marathon',
#   'rainnl',
#   'thats',
#   'good'],
#  ['noo', 'eat', 'homewreckers', 'beach'],
#  ['todo',
#   'list',
#   'bane',
#   'life',
#   'right',
#   'seem',
#   'taken',
#   'life',
#   'completely',
#   'derailing',
#   'mine'],
#  ['amazeballs', 'worst', 'spot', 'mo'],
#  ['nice', 'today', 'wan', 'na', 'somethinng', 'funn'],
#  ['hey', 'sweetie', 'monday'],
#  ['ok', 'didnt', 'really', 'like', 'either'],
#  ['new', 'job'],
#  ['sleepy', 'want', 'go', 'bed', 'continue', 'studying', 'hate'],
#  ['person',
#   'online',
#   'msn',
#   'dont',
#   'add',
#   '500',
#   'people',
#   'msn',
#   'wouldnt',
#   'even',
#   'talk',
#   'anyway',
#   'amp',
#   'wouldnt',
#   'even',
#   'know'],
#  ['20', 'july', 'mariee', 'sioux', 'yeah'],
#  ['near',
#   '80',
#   'weather',
#   'saturday',
#   'gloomy',
#   '46',
#   'degree',
#   'monday',
#   'fair'],
#  ['back', 'hn'],
#  ['bless', 'bet', 'b'],
#  ['want', 'iphone', '3gs'],
#  ['sad', 'turnout', 'ha', 'good', 'election', 'till', 'sure', 'govt', 'hate'],
#  ['contact',
#   'dai',
#   'board',
#   'lot',
#   'c',
#   'missing',
#   'hug',
#   'want',
#   'fix',
#   'though'],
#  ['feel',
#   'sick',
#   'think',
#   'woulda',
#   'learned',
#   'lesson',
#   'first',
#   'time',
#   'thanks',
#   'alot',
#   'costco'],
#  ['good', 'food', 'wine', 'show', 'im', 'sure', 'itll', 'great'],
#  ['ahh',
#   'cant',
#   'believe',
#   '2',
#   'yr',
#   'amp',
#   'cant',
#   'believe',
#   'finally',
#   'say',
#   'quotyoure',
#   'home',
#   '1',
#   'weekquot',
#   'ready',
#   'back'],
#  ['hallie',
#   'get',
#   'lite',
#   'today',
#   'already',
#   'feel',
#   'life',
#   'sucked',
#   'brain'],
#  ['school', 'yes'],
#  ['getting',
#   'madi',
#   'cant',
#   'get',
#   'laptop',
#   'play',
#   'dvdsi',
#   'dunno',
#   'happened'],
#  ['haha',
#   'truecould',
#   'way',
#   'worse',
#   'tell',
#   'hugh',
#   'said',
#   'hi',
#   'fun',
#   'enjoy',
#   'long',
#   'weekend'],
#  ['wish', 'wa'],
#  ['need', 'feel', 'normal'],
#  ['oh',
#   'yeah',
#   'author',
#   'fucking',
#   'great',
#   'song',
#   'never',
#   'get',
#   'old',
#   'seriously',
#   'could',
#   'listen',
#   'hour',
#   'probably'],
#  ['feeling',
#   'crappy',
#   'sore',
#   'everything',
#   'big',
#   'family',
#   'party',
#   'afternoon',
#   'could',
#   'really',
#   'without'],
#  ['got', 'new', 'computer', 'yesterday'],
#  ['great', 'grandmother', 'still', 'sick', 'step', 'dad', 'hospital'],
#  ['whats', 'wrong', 'yesterday', 'haul'],
#  ['going', 'home', 'sydney', 'friday', 'miss', 'puppy'],
#  ['holiday', '2', 'day'],
#  ['liking', 'friend', 'sale'],
#  ['weekend', 'supposed', 'fun', 'homeworkkk'],
#  ['yeah', 'little', 'well', 'really', 'enjoyed'],
#  ['gente',
#   'vamu',
#   'twittar',
#   'delongeday',
#   'delongeday',
#   'delongeday',
#   'delongeday'],
#  ['calling', 'ugly'],
#  ['hey',
#   'miss',
#   'leopard',
#   'print',
#   'wan',
#   'na',
#   'see',
#   'today',
#   'happens',
#   'u',
#   'tell',
#   'ur',
#   'mom',
#   'ur',
#   'resume',
#   'love',
#   'babe'],
#  ['wake', 'feed', 'baby', 'lamb'],
#  ['oh', 'im', 'excited', 'tonight', 'sitting'],
#  ['actually', 'sound', 'great'],
#  ['im',
#   'left',
#   'alone',
#   'lesbian',
#   'twin',
#   'sister',
#   'maggie',
#   'fox',
#   'along',
#   '5',
#   'kid'],
#  ['wish', 'price', 'right', 'came', 'sunday'],
#  ['night', 'hunny', 'amp', 'anytime'],
#  ['sad',
#   'miss',
#   'babe',
#   'gaby',
#   'left',
#   'u',
#   'forsaken',
#   'u',
#   'forward',
#   'live',
#   'heart',
#   'always',
#   'want',
#   'gaby'],
#  ['hell', 'didnt', 'call'],
#  ['lol', 'quite'],
#  ['thanks'],
#  ['wee', 'carpet', 'hate', 'bitin', 'time'],
#  ['love', 'twitter', 'omg', 'new', 'obbsession'],
#  ['4',
#   'new',
#   'emblem',
#   'handed',
#   'e3',
#   'participation',
#   'sure',
#   'check',
#   'profile',
#   'see',
#   'got'],
#  ['yeah', 'ive', 'done', 'need', 'motivation', 'everything', 'else'],
#  ['mix',
#   'little',
#   'cayenne',
#   'pepper',
#   'wit',
#   'lemon',
#   'juice',
#   'snort',
#   'strawok',
#   'quitfeel',
#   'better',
#   'kelkins'],
#  ['awesome', 'quotkarate', 'snif', 'whole', 'body', 'weaponquot'],
#  ['wow', 'long', 'twitter', 'must', 'woken', 'really', 'early'],
#  ['thats', 'friend', 'im', 'drunk', 'tired'],
#  ['lol',
#   'yep',
#   'cant',
#   'say',
#   'quotnoquot',
#   'true',
#   'also',
#   'believe',
#   'giving',
#   'back',
#   'community',
#   'give',
#   'soooo',
#   'much'],
#  ['quot', 'best', 'love', 'give', 'emaili', 'want', 'write', 'cant'],
#  ['wordpress',
#   'upgrade',
#   'ha',
#   'ruined',
#   'blog',
#   'cant',
#   'see',
#   'text',
#   'making',
#   'new',
#   'post',
#   'error',
#   'msg',
#   'everywhere',
#   'admin',
#   'screen',
#   'moving',
#   'blogger'],
#  ['know'],
#  ['funny', 'bayli'],
#  ['daang',
#   'nvm',
#   'tell',
#   'youre',
#   'back',
#   'dont',
#   'waste',
#   'time',
#   'tweeting',
#   'fresh',
#   'tempuramisosushi'],
#  ['mom',
#   'said',
#   'tomm',
#   'goin',
#   'visit',
#   'lil',
#   'brother',
#   'miss',
#   'much',
#   'wonderful',
#   'day'],
#  ['would',
#   'still',
#   'involve',
#   'standing',
#   'lol',
#   'window',
#   'high',
#   'guess',
#   'im',
#   'gon',
#   'na',
#   'go'],
#  ['okill', 'see', 'u'],
#  ['hi',
#   'amanda',
#   'great',
#   'site',
#   'name',
#   'bloggerbustercom',
#   'sent',
#   'email',
#   'via',
#   'contact',
#   'form',
#   'hope',
#   'get'],
#  ['santacruzan', 'good', 'night', 'next', 'michelle', 'right'],
#  ['missing', '2', 'favorite', 'peoplelonely', 'gnight'],
#  ['didnt', 'wan', 'na', 'take', 'get', 'house'],
#  ['hope', 'enjoyed', 'movie', 'see', 'soon', 'babe', 'xoxo'],
#  ['went',
#   'wedding',
#   'today',
#   'almost',
#   'laughed',
#   'loud',
#   'pastor',
#   'said',
#   'quotjesus',
#   'wa',
#   'invited',
#   'today',
#   'never',
#   'refuse',
#   'invitationquot',
#   'fb'],
#  ['enough', 'prawn', 'eat', 'ha', 'flavour', 'never', 'mind', 'drink', 'good'],
#  ['im', 'sooo', 'happy', 'summer', 'vacation', 'lack', 'sleep'],
#  ['got',
#   'one',
#   'right',
#   'two',
#   'packed',
#   'along',
#   'mark',
#   'vi',
#   'mjolnir',
#   'helmet'],
#  ['nice', 'dont', 'want', 'karma', 'bite', 'u', 'back'],
#  ['one', 'day', 'everything', 'get', 'annoys', 'real', 'diana'],
#  ['ha',
#   'keep',
#   'trying',
#   'set',
#   'lunch',
#   'usually',
#   'end',
#   'canceling',
#   'thing',
#   'called',
#   'work'],
#  ['feal', 'ill', 'omg'],
#  ['think',
#   'annoying',
#   'keep',
#   'getting',
#   'twitter',
#   'error',
#   'message',
#   'mobile'],
#  ['hav', 'cold', 'come', 'sneezles'],
#  ['hello', 'nice', 'meet', 'u'],
#  ['joined', 'twitter', 'cuz', 'dog'],
#  ['officially',
#   'father',
#   'day',
#   'east',
#   'coast',
#   'good',
#   'one',
#   'everybody',
#   'rip',
#   'daddy'],
#  ['ahhhh',
#   'got',
#   'ta',
#   'sew',
#   'top',
#   '2',
#   'apron',
#   '4',
#   '3rd',
#   'time',
#   'b',
#   'outside'],
#  ['come', 'im'],
#  ['like', 'confuse', 'people', 'also', 'added', 'wefollow', 'dad'],
#  ['back',
#   'body',
#   'balance',
#   'chilled',
#   'back',
#   'dressing',
#   'gown',
#   'sunday',
#   'paper',
#   'bliss',
#   'looking',
#   'forward',
#   'apprentice',
#   'final',
#   'later'],
#  ['yeah',
#   'next',
#   'week',
#   'weve',
#   'got',
#   '2',
#   'bill',
#   'pay',
#   'sat',
#   'wont',
#   'wait',
#   'come',
#   'first',
#   'unfortunately'],
#  ['wa', 'easy', 'wouldnt', 'frustrated'],
#  ['yes',
#   'lovely',
#   'lie',
#   'infor',
#   'change',
#   'lolcause',
#   'really',
#   'well',
#   'invited',
#   '150people',
#   'yesterday',
#   'none',
#   'joined',
#   'gutted'],
#  ['really', 'lucky'],
#  ['crazybusy',
#   'day',
#   'yet',
#   'atall',
#   'im',
#   'even',
#   'going',
#   'time',
#   'make',
#   'dinner',
#   'blow'],
#  ['like',
#   'album',
#   'lot',
#   'kinda',
#   'mean',
#   'carry',
#   'around',
#   'ipod',
#   'everywhere',
#   'go',
#   'sorta'],
#  ['im', 'following', 'yoooou'],
#  ['saw', 'nice', 'piece'],
#  ['summer', 'school', 'suck'],
#  ['guess', 'porn', 'bot', 'twitter', 'dont', 'like'],
#  ['good',
#   'ride',
#   'suffered',
#   'leg',
#   'cramp',
#   'cut',
#   'short',
#   '75',
#   'mile',
#   'mtb',
#   'tomorrow',
#   'eureka',
#   'spring'],
#  ['spent',
#   'day',
#   'w',
#   'watching',
#   'footie',
#   'amp',
#   'playing',
#   'wii',
#   'heading',
#   'town',
#   'centre',
#   'japanese',
#   'fest',
#   'see',
#   'crazy',
#   'band',
#   'great',
#   'day'],
#  ['yes', 'defently', 'make', 'totally', 'awsomeeee'],
#  ['also',
#   'let',
#   'thou',
#   'guy',
#   'know',
#   'wont',
#   'tweeting',
#   'next',
#   'week',
#   'big',
#   'plan',
#   'stuff',
#   'like'],
#  ['gym',
#   'final',
#   'gym',
#   'session',
#   'barbados',
#   '6',
#   'month',
#   'killing',
#   'worth',
#   'yes',
#   'difference',
#   'body',
#   'none'],
#  ['suuuuuper', 'excited', 'look', 'tide', 'brought', 'haha', 'lt3'],
#  ['sinus',
#   'infection',
#   'still',
#   'kick',
#   'cant',
#   'wait',
#   'till',
#   'go',
#   'awaygt'],
#  ['want', 'bake', 'cake', 'doesnt', 'ingredient', 'house'],
#  ['love', 'perception', 'isnt'],
#  ['dress',
#   'wa',
#   'pink',
#   'loldont',
#   'surprised',
#   'pink',
#   'jockers',
#   'wearin',
#   'dress',
#   'myspace',
#   'lol'],
#  ['get', 'mask'],
#  ['realized', 'think', 'youre', 'month', 'two', 'behind', 'thing'],
#  ['check', 'entire', 'scentsy', 'collection', 'online'],
#  ['hi', 'sun', 'thats', 'exciting'],
#  ['pixar',
#   'making',
#   'monster',
#   'inc',
#   '2',
#   'car',
#   '2',
#   'toy',
#   'story',
#   '3',
#   'awesome',
#   'sure',
#   'thats',
#   'exciting'],
#  ['altone', 'put', 'timeout'],
#  ['ew', 'french'],
#  ['home', 'work'],
#  ['thunder', 'woke', '7', 'thanks', 'thunder'],
#  ['iï½d', 'love'],
#  ['thing', 'like', 'good', 'morning', 'btw'],
#  ['english',
#   'exam',
#   'tomorrow',
#   'hate',
#   'writing',
#   'essay',
#   'mine',
#   'likely',
#   'macbeth'],
#  ['made',
#   'w',
#   'virginiait',
#   'wa',
#   'productive',
#   'drive',
#   'say',
#   'anywaysright',
#   'im',
#   'drying',
#   'clothes',
#   'waiting',
#   'meet',
#   'matt',
#   'lunch'],
#  ['made', 'dinner', 'far', 'salty'],
#  ['jury', 'duty', 'alll', 'week'],
#  ['chris', 'miss', 'sweetheart'],
#  ['succesfully',
#   'avoided',
#   'yummy',
#   'stuff',
#   'sandwich',
#   'van',
#   'bought',
#   'healthy',
#   'salad',
#   'instead'],
#  ['anyone',
#   'suggestionsi',
#   'test',
#   '2',
#   'take',
#   'morning',
#   'amp',
#   'cant',
#   'fall',
#   'asleep'],
#  ['know',
#   'theyre',
#   'playing',
#   'show',
#   'right',
#   'london',
#   'theyre',
#   'even',
#   'stopping',
#   'dublin',
#   'fair'],
#  ['cant',
#   'sit',
#   'inside',
#   'day',
#   'beautiful',
#   'weather',
#   'im',
#   'gone',
#   'walk',
#   'outside'],
#  ['aftermath', 'pepper', 'haircut'],
#  ['cant',
#   'freaking',
#   'sleep',
#   'nearing',
#   '2am',
#   'need',
#   'get',
#   'early',
#   'maybe',
#   'ill',
#   'start',
#   'counting',
#   'sheep'],
#  ['jus', 'didnt', 'wan', 'na', 'feed'],
#  ['well',
#   'stay',
#   'youre',
#   'really',
#   'great',
#   'mother',
#   'im',
#   'sure',
#   'zoey',
#   'appreciates',
#   'hope',
#   'u',
#   'get',
#   'rest',
#   'amp',
#   'get',
#   'well'],
#  ['nite',
#   'nite',
#   'enjoy',
#   'sunday',
#   'god',
#   'bless',
#   'chat',
#   'soon',
#   'take',
#   'care'],
#  ['eaten', 'waaaay', 'much', 'go', '15', 'min', 'lol', 'x'],
#  ['work', 'early', 'today'],
#  ['maybe', 'yes', 'sometimes', 'people', 'appear', 'like', 'person', 'arent'],
#  ['bored',
#   'bf',
#   'ignoring',
#   'play',
#   'psp',
#   'hollyoaks',
#   'sit',
#   'silenceperfect',
#   'idea',
#   'hell'],
#  ['south',
#   'crete',
#   'rock',
#   'agia',
#   'galini',
#   'le',
#   'suck',
#   'though',
#   'try',
#   'komos',
#   'beach'],
#  ['contd',
#   'rephrase',
#   'question',
#   'quotdo',
#   'want',
#   'take',
#   'fwdquot',
#   'reply',
#   'quotyesquot',
#   'someone',
#   'please',
#   'explain',
#   'happened',
#   'im',
#   'lost'],
#  ['today',
#   'may',
#   'day',
#   'happy',
#   'cause',
#   'friend',
#   'going',
#   'going',
#   'much',
#   'fun'],
#  ['love', 'new', 'car'],
#  ['2', 'b', '18', '4', 'job', 'want', '1', 'year', 'still', 'unemployed', '4'],
#  ['love', 'fire', 'winter', 'time'],
#  ['know', 'different', 'note', 'blast', 'tonight', 'â', 'must', 'pumped'],
#  ['hmmmm',
#   'dont',
#   'think',
#   'thats',
#   'always',
#   'case',
#   'though',
#   'seems',
#   'dm',
#   'show',
#   'lil',
#   'dm',
#   'list'],
#  ['dont', 'feel', 'good', 'flu'],
#  ['course', 'one', 'day', 'cant', 'go', 'tolllllld', 'sunday'],
#  ['change',
#   'bio',
#   'might',
#   'exactly',
#   'want',
#   'seen',
#   'future',
#   'still',
#   'suppose'],
#  ['getting', 'ready', 'work', 'boo', 'wish', 'wasnt', 'closing'],
#  ['like',
#   'song',
#   'shes',
#   'maybe',
#   'biggest',
#   'fan',
#   'n',
#   'im',
#   'hugest',
#   'fan',
#   'someday',
#   'wan',
#   'na',
#   'make',
#   'song'],
#  ['love', 'rain', 'get', 'heck', 'good', 'sleep', 'cause'],
#  ['started', 'watchin', 'whale', 'war', 'say', 'sad'],
#  ['woke', 'early', 'people', 'cleaning', 'vent'],
#  ['thinking',
#   'dropping',
#   'tonight',
#   'pinot',
#   'day',
#   'tasting',
#   'since',
#   'cant',
#   'make',
#   'main',
#   'event',
#   'weekend'],
#  ['hey', 'heeey'],
#  ['good', 'trip', 'back', 'least', 'sport', 'mean', 'road', 'clearer'],
#  ['filled',
#   'regret',
#   'didnt',
#   'rattle',
#   'courage',
#   'flirt',
#   'cute',
#   'guy',
#   'petrol',
#   'station'],
#  ['say',
#   'learn',
#   'appreciate',
#   'time',
#   'force',
#   'appreciate',
#   'make',
#   'sense'],
#  ['nod', 'think', 'chatted', 'northampton', 'suffering'],
#  ['end', 'era', 'wa', 'looking', 'ago', 'look', 'good'],
#  ['good', 'luck', 'wthe', 'awardnot', 'vodka'],
#  ['hey', 'safe', 'journey', 'loadsa', 'phunnn', 'tc', 'keep', 'tweeting'],
#  ['heaven', '2', 'year'],
#  ['ok',
#   'looking',
#   'credit',
#   'report',
#   'unpaid',
#   'medical',
#   'bill',
#   'count',
#   'mark',
#   'credit',
#   '2',
#   'unpaid',
#   'high',
#   'medical',
#   'bill',
#   'bad'],
#  ['didnt',
#   'saw',
#   'movie',
#   'yet',
#   'actually',
#   'wa',
#   'planning',
#   'watch',
#   'tomorrow'],
#  ['nalilito', 'nahihilo'],
#  ['believe', 'teethjaw', 'ha', 'problem', 'dentist', 'time', 'guessyay'],
#  ['cool', 'let', 'u', 'know', 'think'],
#  ['wowit', 'must', 'good', 'showim', 'gon', 'na', 'watch', 'come'],
#  ['love', 'spending', 'quality', 'time', 'honey'],
#  ['andy', 'black', 'told', 'bad', 'karma', 'today'],
#  ['tiny', 'url', 'seems', 'broken', 'least', 'moment'],
#  ['computer', 'restarted'],
#  ['ohmygosh', 'know', 'would', 'make', 'night', 'sure', 'lol', 'goodnight'],
#  ['great',
#   'news',
#   'much',
#   'campaigning',
#   'plan',
#   'destroy',
#   'finsbury',
#   'park',
#   'ice',
#   'rink',
#   '17m',
#   'invested',
#   'fixing',
#   'instead'],
#  ['good',
#   'thursday',
#   'morning',
#   'im',
#   'still',
#   'sleepy',
#   'cant',
#   'sleep',
#   'anymore'],
#  ['home',
#   'day',
#   'scale',
#   'one',
#   'ten',
#   '8',
#   'damn',
#   'feel',
#   'old',
#   'compare',
#   'haha',
#   'cute'],
#  ['get', 'u', 'free', 'tea', 'coffee', 'bean'],
#  ['today',
#   'going',
#   'continue',
#   'learning',
#   'dreamweaver',
#   'load',
#   'photoshop',
#   'learn',
#   'next'],
#  ['thanks', 'follow', 'friday', 'mention'],
#  ['choose',
#   'carrot',
#   'snack',
#   'havve',
#   'chip',
#   'ice',
#   'cream',
#   'sandwhiches',
#   'creamcibles',
#   'cooky',
#   'house'],
#  ['phone', 'rebooted', 'sm', 'lost'],
#  ['cheered', 'supported', 'fob', 'didnt', 'get', 'kiss'],
#  ['watching',
#   'film',
#   'annie',
#   'leibovitz',
#   'wondering',
#   'indian',
#   'band',
#   'dont',
#   'take',
#   'photographer',
#   'tour'],
#  ['time',
#   'disconnect',
#   'fantastic',
#   'dinner',
#   'waiting',
#   'great',
#   'friendscant',
#   'get',
#   'enough'],
#  ['love', 'jb', 'amp', 'demi', 'theeir', 'awsome'],
#  ['want', 'sleep', 'thats', 'fucking', 'want'],
#  ['isnt', 'way', 'dc'],
#  ['dude',
#   'bahadtothebone',
#   'aim',
#   'screenname',
#   'lol',
#   'pretty',
#   'clever',
#   'though',
#   'huh',
#   'lol',
#   'oh',
#   'yay',
#   'ill',
#   'visit',
#   'u',
#   'guy',
#   'l8r'],
#  ['thanks'],
#  ['believe', 'sucked', 'earlier', 'also'],
#  ['doesnt', 'wan', 'na', 'study', 'science', 'motivation'],
#  ['doubt', 'keep', 'u', 'know', 'k'],
#  ['hope', 'feel', 'better', 'soon'],
#  ['sad', 'clint', 'hurdle', 'got', 'released', 'liked'],
#  ['wpf',
#   'rendering',
#   'vs2010',
#   'blurred',
#   'look',
#   'awfully',
#   'agree',
#   'suck',
#   'expect',
#   'fixed',
#   'vs10'],
#  ['first', 'h1n1', 'swine', 'flu', 'death', 'reported'],
#  ['life', 'blockbuster', 'movie', '3', '20', 'got', 'slurpee', 'etc'],
#  ['late',
#   'night',
#   'tonight',
#   'wa',
#   'still',
#   'great',
#   'rowlands',
#   'awesome',
#   'lol'],
#  ['chilling',
#   'sun',
#   'england',
#   'thinking',
#   'going',
#   'hardcore',
#   'running',
#   'session',
#   'later'],
#  ['pbarone',
#   'interesting',
#   'people',
#   'following',
#   'list',
#   'result',
#   'reading',
#   'im',
#   'following',
#   'many',
#   'people'],
#  ['yes',
#   'wa',
#   'need',
#   'im',
#   'crunched',
#   'time',
#   'good',
#   'night',
#   'im',
#   'glad',
#   'like',
#   'mac'],
#  ['headed',
#   'cafe',
#   'finish',
#   'paperwork',
#   'shoot',
#   'today',
#   'wa',
#   'cancelled',
#   'last',
#   'minute'],
#  ['well', 'done', 'website', 'look', 'wonderful'],
#  ['would', 'agree'],
#  ['iphone',
#   'guess',
#   'ill',
#   'text',
#   'tweet',
#   'text',
#   'lol',
#   'root',
#   'beer',
#   'win',
#   'aampw',
#   'barqs',
#   'ibc'],
#  ['think',
#   'im',
#   'going',
#   'go',
#   'get',
#   'ben',
#   'amp',
#   'jerry',
#   'cherry',
#   'garcia',
#   'roam',
#   'around',
#   'downtown',
#   'oh',
#   'thats',
#   'right',
#   'dont',
#   'live',
#   'toronto',
#   'anymore'],
#  ['hey', 'thing'],
#  ['run', 'home', 'grocery', 'shop', 'cook', 'storm', 'yum'],
#  ['working'],
#  ['one', 'knife', '2', 'half', 'yearsand', 'gonein', 'instant'],
#  ['got',
#   'smashed',
#   'face',
#   'playing',
#   'soccer',
#   'last',
#   'night',
#   'cut',
#   'gum',
#   'nose'],
#  ['vacation', 'almost', 'done'],
#  ['sorry', 'si', 'ima', 'work', 'dat'],
#  ['im',
#   'shower',
#   'boyfriend',
#   'changing',
#   'twitter',
#   'better',
#   'shave',
#   'leg',
#   'thing',
#   'dangerous',
#   'right'],
#  ['got', 'pair', 'air', 'jordan', '2009s'],
#  ['oh', 'haha', 'much', 'would', 'coast'],
#  ['super', 'sad', 'face'],
#  ['got',
#   'back',
#   'pet',
#   'mart',
#   'got',
#   'musik',
#   'shot',
#   'hella',
#   'cried',
#   'gave',
#   'chip'],
#  ['beautiful'],
#  ['long', 'working', 'day', 'taken', 'tole', 'poor', 'foot', 'need', 'relief'],
#  ['spam', 'rice', 'lunch'],
#  ['miyagis',
#   'chopstick',
#   'think',
#   'ill',
#   'stick',
#   'using',
#   'theyre',
#   'intended',
#   'danielsan',
#   'skils'],
#  ['tackle', 'u', 'make', 'feel', 'better', 'tummy', 'hurt'],
#  ['1st',
#   'time',
#   'since',
#   'ive',
#   'hair',
#   'cut',
#   'short',
#   'ive',
#   'wanted',
#   'ponytail',
#   'blame',
#   'wild',
#   'night',
#   'taking',
#   '50',
#   '2',
#   'work',
#   'hope',
#   'traffic',
#   'light'],
#  ['want',
#   'verterinarian',
#   'doesnt',
#   'want',
#   'major',
#   'biology',
#   'hate',
#   'math'],
#  ['making', 'pizza'],
#  ['right',
#   'tweeps',
#   'im',
#   'spell',
#   'good',
#   'morning',
#   'afternoon',
#   'evening',
#   'fun',
#   'discussing',
#   'heavy',
#   'sunday',
#   'topic'],
#  ['gt',
#   'look',
#   'much',
#   'youve',
#   'qrowwnnn',
#   'remake',
#   'sonq',
#   'pleaseeee',
#   'muahhh'],
#  ['lameurijah', 'lostsad', 'still', 'love', 'though'],
#  ['last', 'day', 'vacation', 'leavin', '7', 'pm'],
#  ['yes', 'doe', 'old', 'enough', 'know', 'fall', 'cheap', 'gimmics'],
# ...
#   'awhile',
#   'trip',
#   'stats',
#   'homework',
#   'booooo'],
#  ['go', 'honey', 'fun'],
#  ['please', 'visit', 'follow', 'blog', 'ask'],
#  ['woooo', 'ipod', 'fixed'],
#  ['shes', 'got', 'look', 'start', 'wednesday', 'right', 'cougar'],
#  ['watching', 'dodgeball', 'haha', 'loove', 'movie', 'goodnight'],
#  ['another', 'saturday', 'bored', 'work', 'need', 'big', 'kid', 'job'],
#  ['mtv', 'movie', 'award', 'live', '12', 'minute', 'sooooo', 'excited'],
#  ['narration',
#   'new',
#   'single',
#   'miracle',
#   'monday',
#   'via',
#   'itunes',
#   'website',
#   'spread',
#   'word',
#   'x'],
#  ['enjoying', 'slow', 'sunday', 'work', 'since', 'church'],
#  ['bus',
#   'amp',
#   'lady',
#   'tiddies',
#   'r',
#   'sssssaaaaagggggiiiiiiing',
#   'ouch',
#   'heart',
#   'go',
#   'thats',
#   'gravity',
#   'fo',
#   'yo'],
#  ['im', 'supposed', 'tidying', 'room', 'much', 'go'],
#  ['wa',
#   'geek',
#   'joke',
#   'tweetdeck',
#   'butchered',
#   'basically',
#   'surprise',
#   'shuffled',
#   'mortal',
#   'coil'],
#  ['cause',
#   'liked',
#   'namei',
#   'wa',
#   'thinkin',
#   '2',
#   'change',
#   '2',
#   '4',
#   'whileim',
#   'sassy',
#   'chick'],
#  ['cant', 'wait', 'see', 'clip'],
#  ['ight', 'thx', 'hun'],
#  ['got', 'home', 'netty', 'lost'],
#  ['ooooh',
#   'noooo',
#   'come',
#   'back',
#   'silly',
#   'cat',
#   'maybe',
#   'hell',
#   'wander',
#   'far'],
#  ['usually', 'badand', 'wouldnt', 'bad', 'could', 'logged', 'pc'],
#  ['im', 'sorrry', 'cathy'],
#  ['yea'],
#  ['busy',
#   'like',
#   'buzzing',
#   'bee',
#   'like',
#   'cant',
#   'wait',
#   'hear',
#   'sound',
#   'like'],
#  ['wan', 'na', 'play', 'ballloono', 'reply', 'ill', 'make', 'room'],
#  ['interesting', 'mix'],
#  ['damn', 'right', 'aint', 'arguing', 'snr', 'rkc', 'day', 'week'],
#  ['degustation',
#   'menu',
#   'sound',
#   'pretentious',
#   'thinking',
#   'word',
#   'degustationtoughnot',
#   'itthe',
#   'food',
#   'make',
#   'name'],
#  ['tofurky', 'owe', 'new', 'keyboard'],
#  ['youre', 'welcome', 'bashful', 'kick', 'pretty', 'cute'],
#  ['wish', 'wa', 'deleterewind', 'button', 'life'],
#  ['sniff', 'ha', 'cancelled', 'sunday', 'gig', 'troubadour'],
#  ['pic',
#   'old',
#   'computer',
#   'camera',
#   'software',
#   'installed',
#   'check',
#   'group',
#   'rav',
#   'spoiler'],
#  ['didnt', 'want', 'today', 'end', 'dang', 'itoh', 'well', 'abt'],
#  ['congrats',
#   'roger',
#   'federer',
#   'winning',
#   'french',
#   'open',
#   '14',
#   'grand',
#   'slam',
#   'hope',
#   'isnt',
#   'end'],
#  ['hp', 'computer', 'funny', 'updating', 'process', 'take', 'long', 'time'],
#  ['mom', 'getting', 'japan', 'today', 'well', 'surely', 'miss'],
#  ['oh',
#   'didnt',
#   'know',
#   'registered',
#   'hmm',
#   'hopefully',
#   'sent',
#   'devs',
#   'join',
#   'sale'],
#  ['got', 'paiiiiiiid', 'let', 'get', 'laiiiiiidddd'],
#  ['argh', 'ugly', 'twitpic', 'see', 'error', 'made'],
#  ['wahhh',
#   'still',
#   'sick',
#   'first',
#   'day',
#   'school',
#   'todayi',
#   'dont',
#   'class',
#   'tho',
#   'sick',
#   'go',
#   'addbooo'],
#  ['brilliant', 'brilliant', 'love', 'robinson', 'callahan', 'book'],
#  ['much', 'luck', 'finding', 'perfect', 'hols'],
#  ['see', 'wicked', 'defy', 'gravity', 'cara', 'excited'],
#  ['still', 'working', 'makeup', 'workugh'],
#  ['know', 'anymore'],
#  ['wow',
#   'lucky',
#   'would',
#   'ki',
#   'well',
#   'probably',
#   'kill',
#   'yeah',
#   'amazing',
#   'lt3',
#   'hope',
#   'great',
#   'time',
#   'god',
#   'blessx'],
#  ['dewd', 'whats'],
#  ['wa',
#   'okay',
#   'wa',
#   'nervous',
#   'though',
#   'think',
#   'let',
#   'show',
#   'mafia',
#   'yay',
#   'whens'],
#  ['grandmother',
#   'still',
#   'fake',
#   'rotary',
#   'phone',
#   'couldve',
#   'spray',
#   'painted'],
#  ['feeling', 'wa', 'one', 'night', 'stand', 'dont', 'mean', 'much', 'thought'],
#  ['nope', 'xl', 'wa', 'first', 'one'],
#  ['woooohooo', 'moon', 'walking', 'dinosaur', 'cursor'],
#  ['never',
#   'making',
#   'sure',
#   'u',
#   'dont',
#   'ruin',
#   'good',
#   'thought',
#   'wa',
#   'top',
#   'notch',
#   'ace',
#   'boon',
#   'coonsi',
#   'never',
#   'get',
#   'promo',
#   'help'],
#  ['btw', 'know', 'mean', 'cant', 'get', 'image', 'head'],
#  ['one',
#   'reason',
#   'still',
#   'go',
#   'church',
#   'pastor',
#   'really',
#   'awesome',
#   'organist',
#   'leaving'],
#  ['definitely', 'got', '125', 'something', 'yay'],
#  ['goodbye', 'crown', 'point'],
#  ['thats', 'nice', 'one'],
#  ['supposed',
#   'unrelated',
#   'storywise',
#   'new',
#   'part',
#   'fallout',
#   'series',
#   'theyre',
#   'working',
#   'name'],
#  ['wa',
#   'cool',
#   'seeing',
#   'yesterday',
#   'yep',
#   'name',
#   'class',
#   'man',
#   'tell',
#   'got',
#   'scissors',
#   'time',
#   'cuz',
#   'wig',
#   'neeeds'],
#  ['germany', 'kick', 'serious', 'come', 'visit'],
#  ['everyones', 'house', 'want', 'sleep'],
#  ['last', 'one', 'may', 'best', 'ever', 'heh'],
#  ['fun',
#   'experimenting',
#   'lovely',
#   'new',
#   'eyeshadow',
#   'dont',
#   'suit',
#   'fake',
#   'eyelash',
#   'though',
#   'sososo',
#   'excited',
#   'patrick',
#   'wolf',
#   'tomorrow'],
#  ['haha', 'im', 'tired', 'around', 'im', 'bed'],
#  ['love', 'big', 'bang', 'theory', 'grows', 'every', 'day'],
#  ['could', 'watch', 'n', 'r', 'amazing'],
#  ['right',
#   'away',
#   'shower',
#   'get',
#   'bus',
#   'glasgow',
#   'sure',
#   'train',
#   'running',
#   'co',
#   'wa',
#   'bad',
#   'fire',
#   'near',
#   'line',
#   'couple',
#   'day',
#   'ago'],
#  ['jb', 'dong', 'ke', 'casa', 'im', 'bored', 'lonely'],
#  ['cupcake', 'would', 'totally', 'hit', 'spot', 'right'],
#  ['im', 'getting', 'tired', 'long', 'day', 'early', 'night', 'fun'],
#  ['fellow', 'student', 'japan'],
#  ['watching', 'lion', 'king'],
#  ['woke',
#   '530',
#   'nice',
#   'hot',
#   'shower',
#   'got',
#   'lot',
#   'house',
#   'work',
#   'doneâ',
#   'trying',
#   'assignment',
#   'thursday'],
#  ['always',
#   'fun',
#   'watch',
#   'link',
#   'idea',
#   'tweeted',
#   'day',
#   'ago',
#   'circle',
#   'back',
#   'thru',
#   'mass',
#   'like',
#   'new',
#   'news'],
#  ['today', 'daddy', 'birthday', 'miss', 'wish', 'wa', 'home', 'hug', 'kiss'],
#  ['know',
#   'havent',
#   'performed',
#   'long',
#   'maybe',
#   'time',
#   'karaoke',
#   'session',
#   'hehehe'],
#  ['1',
#   'robin',
#   'hood',
#   'writer',
#   'terrible',
#   '2',
#   'mean',
#   'much',
#   '3',
#   'make',
#   'robin',
#   'douche',
#   '4',
#   'distracting',
#   'papaloxley',
#   'dws',
#   'shakespeare'],
#  ['dude', 'pic', 'longer', 'hair', 'duh', 'thanks', 'noticing', 'hahaha'],
#  ['forensics', 'always', 'fun', 'time'],
#  ['sitting',
#   'church',
#   'mixing',
#   'joel',
#   'rowling',
#   'later',
#   'today',
#   'im',
#   'always',
#   'busy'],
#  ['need',
#   'gym',
#   'body',
#   'ache',
#   'including',
#   'finger',
#   'today',
#   'afternoon',
#   'yard',
#   'work',
#   'today',
#   'fun',
#   'fun',
#   'fun'],
#  ['inspection',
#   'comic',
#   'sans',
#   'thought',
#   'wa',
#   'slight',
#   'variation',
#   'using',
#   'capital',
#   'confused',
#   'bit'],
#  ['alright', 'well', 'let', 'know', 'good', 'night'],
#  ['finally', 'found', 'dc', 'quarter', 'still', 'puerto', 'rico'],
#  ['changed', 'picture', 'think', 'one', 'really', 'capture', 'brown', 'part'],
#  ['hope', 'go', 'well'],
#  ['watching', 'anastasia', 'havent', 'seen', 'forever'],
#  ['really',
#   'want',
#   'go',
#   'first',
#   'time',
#   'found',
#   'cassiopeia',
#   'indo',
#   'gathering'],
#  ['one', 'three', 'besties', 'argentina', 'sleepover'],
#  ['hehe',
#   'pizza',
#   'huuuuge',
#   'gon',
#   'na',
#   'good',
#   '__',
#   'wish',
#   'munchies',
#   'right'],
#  ['watched',
#   'new',
#   'final',
#   'destination',
#   'trailer',
#   'may',
#   'never',
#   'trust',
#   'automated',
#   'car',
#   'wash'],
#  ['good',
#   'luck',
#   'im',
#   'race',
#   'life',
#   'local',
#   'park',
#   'today',
#   'look',
#   'like',
#   'heaven',
#   'open'],
#  ['felt', 'like', 'bakin', 'cake', 'didnt', 'ingredient'],
#  ['read',
#   'potty',
#   'training',
#   'usually',
#   'take',
#   '8',
#   'month',
#   '8',
#   'month',
#   'oh',
#   'lord',
#   'almost',
#   'started',
#   'cry'],
#  ['wa',
#   'smooth',
#   'download',
#   'experience',
#   'im',
#   'mad',
#   'cant',
#   'use',
#   'feature'],
#  ['take', 'deep', 'breath', 'focus', '1', 'thing', 'time'],
#  ['writing', 'text', 'adventure', 'via'],
#  ['move', 'mine', '12', 'parking', 'house', 'suck'],
#  ['hope', 'u', 'great', 'day', 'tay'],
#  ['talking',
#   'barry',
#   'myspace',
#   'shannon',
#   'msn',
#   'slowly',
#   'dying',
#   'away',
#   'cry',
#   'vodka',
#   'fault'],
#  ['damn', 'pizza', 'juss', 'burned', 'waiting', 'baguette'],
#  ['keith', 'urban', 'concert', 'missed', 'taylor', 'swift'],
#  ['im',
#   'bored',
#   'im',
#   'watching',
#   'old',
#   'eps',
#   'weed',
#   'onlinebut',
#   'new',
#   'season',
#   'start',
#   'tomorrow',
#   'hell',
#   'yes'],
#  ['woke', 'myrtle', 'beach', 'shopping', 'bitch'],
#  ['picture',
#   'show',
#   'follow',
#   'swear',
#   'im',
#   'tired',
#   'goodnight',
#   'everyone',
#   'pyro',
#   'wonderful',
#   'lt3'],
#  ['dont',
#   'get',
#   'whats',
#   'going',
#   'sophie',
#   'hahaha',
#   'il',
#   'work',
#   'eventually'],
#  ['work', 'kindle', 'uncubicled'],
#  ['found',
#   'dampg',
#   'light',
#   'blue',
#   'nordstrom',
#   'rack',
#   '20',
#   'buck',
#   'le',
#   'place',
#   'score'],
#  ['working', 'breakfast', 'future', 'web', 'apps', 'roadshow', 'bristol'],
#  ['guy'],
#  ['guess', 'wasnt', 'meant'],
#  ['discovered',
#   'sock',
#   'monkey',
#   'via',
#   'amazing',
#   'feel',
#   'inspired',
#   'screw',
#   'revising',
#   '4exams',
#   'let',
#   'make',
#   'sock',
#   'monkey',
#   'x'],
#  ['hyperrr', 'aaahhhh', 'text', 'meee', 'let', 'doooo', 'something'],
#  ['back',
#   'weekend',
#   'wine',
#   'work',
#   'exactly',
#   'classic',
#   'pairing',
#   'puling',
#   'nighter'],
#  ['still', 'dont', 'like', 'im', 'praying', 'people', 'dont', 'kill', 'cudi'],
#  ['sts125',
#   'day',
#   '7',
#   'highlight',
#   'hd',
#   'trying',
#   'day',
#   'wa',
#   'great',
#   'see',
#   'bruteforcing',
#   'always',
#   'option'],
#  ['speaking',
#   'alone',
#   'dark',
#   'street',
#   'see',
#   'camera',
#   'holding',
#   'arm',
#   'sad'],
#  ['working',
#   'hard',
#   'tonight',
#   'got',
#   'ta',
#   'love',
#   '2nd',
#   'job',
#   'least',
#   'get',
#   'good',
#   'exercise',
#   'valet'],
#  ['best', 'bros', 'working', '4th', 'july', 'suck'],
#  ['okay', 'get', 'clean'],
#  ['luv', 'u', 'called', 'called'],
#  ['cooking', 'momma', 'secret', 'beef', 'tip', 'recipe'],
#  ['ahhhhh', 'great', 'feelings'],
#  ['hahaha',
#   'niene',
#   'ur',
#   'soo',
#   'smart',
#   'lmao',
#   'think',
#   'good',
#   'lookin',
#   'whts',
#   'gurlie',
#   'come',
#   'home',
#   'weekend'],
#  ['feel', 'throat', 'tightening', 'im', 'gettin', 'sick', 'ima', 'flip'],
#  ['im', 'taking', 'nap', 'heading', 'mom', 'hopefully', 'fun', 'tonight'],
#  ['wan',
#   'na',
#   'see',
#   'nkotb',
#   'soooo',
#   'bad',
#   'lol',
#   'cuz',
#   'tried',
#   'get',
#   'ticket',
#   'awhile',
#   'back',
#   '1',
#   'show',
#   'wa',
#   'sold',
#   'fun'],
#  ['busy',
#   'helping',
#   'aunt',
#   'create',
#   'avp',
#   'sunday',
#   'weve',
#   'working',
#   'like',
#   'three',
#   'hour',
#   'wan',
#   'na',
#   'watch',
#   'tv',
#   'hah'],
#  ['yeah',
#   'well',
#   'remains',
#   'seen',
#   'impact',
#   'make',
#   'certainly',
#   'meet',
#   'need',
#   'leadership',
#   'creativity'],
#  ['eyetv',
#   'need',
#   'convert',
#   'recorded',
#   'tv',
#   'show',
#   'different',
#   'format',
#   'old',
#   'g5',
#   'take',
#   'two',
#   'age',
#   'one',
#   'forever'],
#  ['welcome', 'look', 'forward', 'stimulating', 'discussion', 'barcampers'],
#  ['probably', 'checked', 'leaving', 'house'],
#  ['omg',
#   'pickn',
#   'floor',
#   'acdc',
#   'ottawa',
#   'august',
#   '10th',
#   'thats',
#   'kooli',
#   'long',
#   'live',
#   'rock'],
#  ['havent',
#   'bought',
#   'tix',
#   'yet',
#   'dc',
#   'cause',
#   'dont',
#   'wan',
#   'na',
#   'leave',
#   'dog',
#   'pathetic',
#   'matt',
#   'nice',
#   'though',
#   'got',
#   'ta',
#   'get'],
#  ['worry', 'friend', 'sweet', 'dream', 'see', 'ya', 'later'],
#  ['watchin', 'charm', 'school', 'looooove', 'guy'],
#  ['brownie', 'oven', 'pie', 'done', 'hooray', 'baking', 'yummy', 'thing'],
#  ['happy', 'happy', 'birthday'],
#  ['kno', 'grr', 'ill', 'work', '2night', 'honest', 'lol'],
#  ['hey', 'wa', 'hotel', 'site', 'lookin', 'day'],
#  ['blipfm', 'ï½', 'issue', 'ï½', 'imeem', 'cant', 'ï½', 'amp', 'ï½'],
#  ['done', 'revision', 'day', 'phew', 'lt3'],
#  ['working', 'real', 'proud'],
#  ['gots', 'sniffle'],
#  ['got', 'mouse', 'ear', 'club', '33'],
#  ['tired', 'able', 'sleep', 'get', '630', 'work'],
#  ['ok',
#   'dont',
#   'rock',
#   'suck',
#   'honest',
#   'soon',
#   'find',
#   'drummer',
#   'actually',
#   'drum',
#   'show',
#   'u'],
#  ['yknow', 'hate', 'thefact', '2', 'hour', 'serious', 'fml'],
#  ['hangover',
#   'far',
#   'one',
#   'funniest',
#   'movie',
#   'ive',
#   'ever',
#   'seen',
#   'entire',
#   'life',
#   'holla',
#   'good',
#   'time'],
#  ['weird', 'norah', 'always', 'work', 'calm'],
#  ['please',
#   'helpwhere',
#   'search',
#   'know',
#   'website',
#   'something',
#   'list',
#   'forgot'],
#  ['well', 'done', 'diversity', 'deserved', 'win'],
#  ['craigslist',
#   'new',
#   'gamestop',
#   'playing',
#   'skate',
#   '2',
#   'lunch',
#   'use',
#   'quotmarket',
#   'researchquot',
#   'quotguilty',
#   'pleasuresquot'],
#  ['serious', 'suck'],
#  ['suck', 'dnt', 'get', 'hear', 'happened'],
#  ['go', 'ahead', 'cash'],
#  ['never', 'one', 'dont', 'one', 'cg', 'dont', 'forget', 'get', 'wine'],
#  ['paperwork', 'play', 'ufcundisputed', 'im', 'hyped', 'finish', 'vocal'],
#  ['hear', 'ya'],
#  ['ohhhhh', 'okay', 'hey'],
#  ['missing', 'twilight', 'ppl', 'r', 'u', 'lol', 'rob', 'talk', 'today'],
#  ['back',
#   'baseball',
#   'game',
#   'trump',
#   'owns',
#   'raw',
#   'really',
#   'need',
#   'watch',
#   'raw',
#   'find',
#   'happened',
#   'feel',
#   'lost',
#   'fun',
#   'tonight'],
#  ['tick', 'tick', 'tick', 'tickthis', 'taking', 'long', 'time'],
#  ['one',
#   'celebrity',
#   'crush',
#   'forgot',
#   'mention',
#   'last',
#   'night',
#   'geof',
#   'ace',
#   'cake',
#   'really',
#   'celebrity',
#   'show'],
#  ['cancel', 'treasure', 'hunt', 'part', 'bday', 'party', 'bc', 'rain'],
#  ['honey', 'keep', 'head', 'eye', 'open'],
#  ['haha', 'thankiies'],
#  ['obrigadothanks',
#   '15000',
#   'follower',
#   'obrigado',
#   'pelo',
#   'carinho',
#   'de',
#   'todos',
#   'brunoswell',
#   'visit',
#   'blog',
#   'blogpop'],
#  ['work', 'god', 'day', 'drag', '14', 'hour', '2', 'go', 'nikkimouse'],
#  ['yes',
#   'princess',
#   'im',
#   'jamaican',
#   'dont',
#   'music',
#   'videosunless',
#   'im',
#   'lead',
#   'girl'],
#  ['morning',
#   'tweeps',
#   'id',
#   'like',
#   'write',
#   'something',
#   'interesting',
#   'let'],
#  ['hoping',
#   'honey',
#   'get',
#   'feeling',
#   'better',
#   'poor',
#   'baby',
#   'gots',
#   'sore',
#   'throat'],
#  ['haha', 'got', 'ta', 'love', 'ok', 'hazzza'],
#  ['working', 'dis', 'beautiful', 'monday', 'bermuda'],
#  ['probably',
#   'theyre',
#   'pretty',
#   'great',
#   'operation',
#   'going',
#   'website',
#   'tho',
#   'im',
#   'sure',
#   'ull',
#   'romanced',
#   'variety'],
#  ['remember',
#   'blessing',
#   'come',
#   'mark',
#   'sure',
#   'ur',
#   'right',
#   'spot',
#   'receive'],
#  ['yeah', 'miniclass', 'reunion', 'im', 'going', 'miss', 'clara', 'hour'],
#  ['packed', 'ready', '2', 'go', 'home', 'xxx'],
#  ['jejejeje', 'yeah', 'awesome', 'thank', 'hope', 'u', 'awesome', 'day'],
#  ['watching', 'secret', 'life', 'yay'],
#  ['really', 'wan', 'na', 'go', 'australia', 'england'],
#  ['darker',
#   'thn',
#   'wa',
#   '4',
#   'day',
#   'ago',
#   'wondering',
#   'wether',
#   'tell',
#   'oliver'],
#  ['imagine', 'im', 'good', 'thx'],
#  ['work', 'slow', 'tonight', 'tired', 'amp', 'feeling', 'well'],
#  ['tru', 'tomorrow', 'im', 'going', 'lady'],
#  ['dont', 'one', 'haha'],
#  ['like'],
#  ['hangin', 'home', 'bored', 'trying', 'figure', 'im', 'going', 'today'],
#  ['4', 'day', 'graduation', 'carolina'],
#  ['ive',
#   'wondering',
#   'big',
#   'one',
#   'went',
#   'cant',
#   'find',
#   'anywhere',
#   'maybe',
#   'lent',
#   'little',
#   'one',
#   'broke'],
#  ['wish',
#   'id',
#   'known',
#   'earlier',
#   'twitter',
#   'one',
#   'underrated',
#   'comedian',
#   'around'],
#  ['waiting',
#   'disc',
#   'burn',
#   'racing',
#   'driving',
#   'music',
#   'feeling',
#   'clean',
#   'roommate',
#   'must',
#   'cleaned',
#   'shower'],
#  ['really',
#   'really',
#   'really',
#   'wish',
#   'fanfic',
#   'chapers',
#   'would',
#   'released',
#   'oh',
#   'also',
#   'wish',
#   'legal',
#   'system',
#   'collapse'],
#  ['thanks'],
#  ['preparing', 'lesson', 'tomorrow', 'im', 'sick', 'lot', 'today'],
#  ['yur', 'welcome'],
#  ['easy', 'ready', 'go', 'nite', 'nite'],
#  ['ahhh', 'cool', 'wrost', 'part', 'might', 'go', 'soon', 'x'],
#  ['set',
#   'sky',
#   'looking',
#   'fwd',
#   'watching',
#   'eric',
#   'oasis',
#   'shud',
#   'good',
#   'looking',
#   'like',
#   'long',
#   'old',
#   'day',
#   'rain'],
#  ['cant', 'believe', 'broke'],
#  ['im', 'currently', 'spammed'],
#  ['uuh',
#   'ooh',
#   'got',
#   'cough',
#   'damn',
#   'mean',
#   'medicine',
#   'aaarrgghhhh',
#   'whats',
#   'best',
#   'cough',
#   'med',
#   'tweepswhat',
#   'u',
#   'recommend'],
#  ...]

# %%
word2vec = Word2Vec(word_list, vector_size=embedding_length, workers=8, min_count=1)

# %%
print("Vocabolary length :",len(word2vec.wv.key_to_index))
word2vec.wv.key_to_index
# Out:
# Vocabolary length : 13914
# {'im': 0,
#  'day': 1,
#  'wa': 2,
#  'good': 3,
#  'get': 4,
#  'like': 5,
#  'got': 6,
#  'go': 7,
#  'dont': 8,
#  'u': 9,
#  'today': 10,
#  'love': 11,
#  'work': 12,
#  'going': 13,
#  'cant': 14,
#  'time': 15,
#  'back': 16,
#  'one': 17,
#  'know': 18,
#  'lol': 19,
#  'want': 20,
#  'see': 21,
#  'na': 22,
#  'well': 23,
#  'really': 24,
#  'think': 25,
#  'still': 26,
#  'night': 27,
#  'home': 28,
#  'new': 29,
#  '2': 30,
#  'ha': 31,
#  'oh': 32,
#  'thanks': 33,
#  'amp': 34,
#  'need': 35,
#  'miss': 36,
#  'make': 37,
#  'feel': 38,
#  'last': 39,
#  'tomorrow': 40,
#  'much': 41,
#  'morning': 42,
#  'ill': 43,
#  'happy': 44,
#  'great': 45,
#  'thats': 46,
#  'hope': 47,
#  'haha': 48,
#  'wish': 49,
#  'twitter': 50,
#  'tonight': 51,
#  'didnt': 52,
#  'fun': 53,
#  'right': 54,
#  'thing': 55,
#  'nice': 56,
#  'would': 57,
#  'way': 58,
#  'sad': 59,
#  'friend': 60,
#  'bad': 61,
#  'week': 62,
#  'come': 63,
#  'getting': 64,
#  'better': 65,
#  'gon': 66,
#  'say': 67,
#  'hey': 68,
#  'sorry': 69,
#  'watching': 70,
#  'look': 71,
#  'wait': 72,
#  'sleep': 73,
#  'ive': 74,
#  'youre': 75,
#  'could': 76,
#  'people': 77,
#  'school': 78,
#  'though': 79,
#  'yeah': 80,
#  'bed': 81,
#  'let': 82,
#  '4': 83,
#  'wan': 84,
#  'show': 85,
#  'soon': 86,
#  'guy': 87,
#  'awesome': 88,
#  'weekend': 89,
#  'hour': 90,
#  'life': 91,
#  'hate': 92,
#  'little': 93,
#  'best': 94,
#  'year': 95,
#  'never': 96,
#  'working': 97,
#  'watch': 98,
#  'yes': 99,
#  'girl': 100,
#  'long': 101,
#  'take': 102,
#  'even': 103,
#  'tweet': 104,
#  'done': 105,
#  'next': 106,
#  'thank': 107,
#  'x': 108,
#  'please': 109,
#  'first': 110,
#  'movie': 111,
#  'always': 112,
#  'feeling': 113,
#  'ur': 114,
#  'tired': 115,
#  'house': 116,
#  'keep': 117,
#  'sure': 118,
#  'another': 119,
#  'song': 120,
#  'help': 121,
#  'ok': 122,
#  'sick': 123,
#  'yet': 124,
#  'wont': 125,
#  'phone': 126,
#  'suck': 127,
#  'yay': 128,
#  'guess': 129,
#  'lost': 130,
#  'finally': 131,
#  'doesnt': 132,
#  'everyone': 133,
#  'ready': 134,
#  'something': 135,
#  'summer': 136,
#  'made': 137,
#  'baby': 138,
#  'thought': 139,
#  'trying': 140,
#  'mom': 141,
#  'pretty': 142,
#  'old': 143,
#  'away': 144,
#  'already': 145,
#  '3': 146,
#  'ever': 147,
#  'wow': 148,
#  'looking': 149,
#  'bit': 150,
#  'hear': 151,
#  'maybe': 152,
#  'check': 153,
#  'early': 154,
#  'rain': 155,
#  'amazing': 156,
#  'someone': 157,
#  'car': 158,
#  'tell': 159,
#  'find': 160,
#  'cool': 161,
#  'bored': 162,
#  'lot': 163,
#  'sound': 164,
#  'later': 165,
#  'hot': 166,
#  'nothing': 167,
#  'follow': 168,
#  'went': 169,
#  'coming': 170,
#  'big': 171,
#  'id': 172,
#  'havent': 173,
#  'pic': 174,
#  'also': 175,
#  'omg': 176,
#  'hurt': 177,
#  '1': 178,
#  'actually': 179,
#  'yesterday': 180,
#  'waiting': 181,
#  'live': 182,
#  'game': 183,
#  'stuff': 184,
#  'try': 185,
#  'weather': 186,
#  'world': 187,
#  'start': 188,
#  'play': 189,
#  'party': 190,
#  'n': 191,
#  'ta': 192,
#  'lt3': 193,
#  'god': 194,
#  'two': 195,
#  'excited': 196,
#  'call': 197,
#  'hi': 198,
#  'follower': 199,
#  'isnt': 200,
#  'damn': 201,
#  'doe': 202,
#  'glad': 203,
#  'found': 204,
#  'birthday': 205,
#  'cry': 206,
#  'around': 207,
#  'aww': 208,
#  'said': 209,
#  'might': 210,
#  'shes': 211,
#  'ya': 212,
#  'must': 213,
#  'mean': 214,
#  'stop': 215,
#  'class': 216,
#  'man': 217,
#  'music': 218,
#  'monday': 219,
#  'woke': 220,
#  'making': 221,
#  'eat': 222,
#  'give': 223,
#  'playing': 224,
#  'saw': 225,
#  'welcome': 226,
#  'sun': 227,
#  'saturday': 228,
#  'dog': 229,
#  'put': 230,
#  'least': 231,
#  'win': 232,
#  'hard': 233,
#  'ago': 234,
#  'sunday': 235,
#  'stay': 236,
#  'many': 237,
#  'exam': 238,
#  'ugh': 239,
#  'end': 240,
#  'may': 241,
#  'since': 242,
#  'job': 243,
#  'okay': 244,
#  'lunch': 245,
#  'read': 246,
#  'without': 247,
#  'left': 248,
#  'mother': 249,
#  'use': 250,
#  'listening': 251,
#  'every': 252,
#  'month': 253,
#  'tho': 254,
#  'finished': 255,
#  'boy': 256,
#  'friday': 257,
#  'following': 258,
#  'cause': 259,
#  'talk': 260,
#  'enjoy': 261,
#  'cute': 262,
#  'poor': 263,
#  'mine': 264,
#  'far': 265,
#  'head': 266,
#  'outside': 267,
#  'fan': 268,
#  'anyone': 269,
#  'cold': 270,
#  'luck': 271,
#  'missing': 272,
#  'dad': 273,
#  'everything': 274,
#  'totally': 275,
#  'food': 276,
#  'late': 277,
#  'hair': 278,
#  'trip': 279,
#  'shit': 280,
#  'missed': 281,
#  'wasnt': 282,
#  'family': 283,
#  'buy': 284,
#  'hahaha': 285,
#  'believe': 286,
#  'beautiful': 287,
#  'sweet': 288,
#  'minute': 289,
#  'gone': 290,
#  'book': 291,
#  'free': 292,
#  'dinner': 293,
#  'probably': 294,
#  'post': 295,
#  'update': 296,
#  'funny': 297,
#  'plan': 298,
#  'whats': 299,
#  'super': 300,
#  '5': 301,
#  'video': 302,
#  'anything': 303,
#  'almost': 304,
#  'money': 305,
#  'idea': 306,
#  'seen': 307,
#  'r': 308,
#  'b': 309,
#  'theyre': 310,
#  'eye': 311,
#  'till': 312,
#  'crazy': 313,
#  'w': 314,
#  'sooo': 315,
#  'xx': 316,
#  'wrong': 317,
#  'enough': 318,
#  'either': 319,
#  'name': 320,
#  'run': 321,
#  'beach': 322,
#  'watched': 323,
#  'part': 324,
#  'picture': 325,
#  'iphone': 326,
#  'half': 327,
#  'couldnt': 328,
#  'took': 329,
#  'forward': 330,
#  'headache': 331,
#  'hopefully': 332,
#  'bought': 333,
#  'kind': 334,
#  'eating': 335,
#  'blog': 336,
#  'thinking': 337,
#  'text': 338,
#  'goodnight': 339,
#  'cat': 340,
#  'open': 341,
#  'taking': 342,
#  'alone': 343,
#  'sister': 344,
#  'til': 345,
#  'face': 346,
#  'wanted': 347,
#  'whole': 348,
#  'lovely': 349,
#  'brother': 350,
#  'reading': 351,
#  'p': 352,
#  'meet': 353,
#  'leave': 354,
#  'dream': 355,
#  'season': 356,
#  'using': 357,
#  'coffee': 358,
#  '7': 359,
#  'stupid': 360,
#  'tv': 361,
#  'email': 362,
#  'hehe': 363,
#  'real': 364,
#  'word': 365,
#  'else': 366,
#  'forgot': 367,
#  'awake': 368,
#  'kid': 369,
#  'worry': 370,
#  'hug': 371,
#  'raining': 372,
#  'room': 373,
#  'true': 374,
#  '6': 375,
#  'study': 376,
#  'came': 377,
#  'ticket': 378,
#  'quite': 379,
#  'place': 380,
#  'reply': 381,
#  'leaving': 382,
#  'soo': 383,
#  'boring': 384,
#  'add': 385,
#  'full': 386,
#  'photo': 387,
#  'busy': 388,
#  'called': 389,
#  'write': 390,
#  'link': 391,
#  'move': 392,
#  'visit': 393,
#  'online': 394,
#  'anymore': 395,
#  'able': 396,
#  'rock': 397,
#  'set': 398,
#  'close': 399,
#  'breakfast': 400,
#  'hell': 401,
#  'together': 402,
#  'drink': 403,
#  'test': 404,
#  'hello': 405,
#  'started': 406,
#  'lmao': 407,
#  'problem': 408,
#  '10': 409,
#  'sigh': 410,
#  'bout': 411,
#  'wonderful': 412,
#  'story': 413,
#  'cuz': 414,
#  'heart': 415,
#  'church': 416,
#  'office': 417,
#  'le': 418,
#  'kinda': 419,
#  'concert': 420,
#  'care': 421,
#  'sore': 422,
#  'news': 423,
#  'broke': 424,
#  'rest': 425,
#  'told': 426,
#  'computer': 427,
#  'talking': 428,
#  'evening': 429,
#  'list': 430,
#  'tried': 431,
#  'lady': 432,
#  'send': 433,
#  'change': 434,
#  'asleep': 435,
#  'boo': 436,
#  'writing': 437,
#  'aw': 438,
#  'lil': 439,
#  'short': 440,
#  '8': 441,
#  'bday': 442,
#  'definitely': 443,
#  'break': 444,
#  'soooo': 445,
#  'hit': 446,
#  'city': 447,
#  'afternoon': 448,
#  'mad': 449,
#  'ice': 450,
#  'dude': 451,
#  'tea': 452,
#  'hand': 453,
#  'xxx': 454,
#  'goin': 455,
#  'em': 456,
#  'sunny': 457,
#  'lucky': 458,
#  'yep': 459,
#  'sleepy': 460,
#  'facebook': 461,
#  'interesting': 462,
#  'stuck': 463,
#  'heading': 464,
#  'hungry': 465,
#  'dead': 466,
#  'thx': 467,
#  'instead': 468,
#  'tweeting': 469,
#  'award': 470,
#  'sleeping': 471,
#  'ate': 472,
#  'english': 473,
#  'finish': 474,
#  'laptop': 475,
#  'shopping': 476,
#  'ah': 477,
#  'vote': 478,
#  'person': 479,
#  'ride': 480,
#  'paper': 481,
#  'meeting': 482,
#  'awww': 483,
#  'tour': 484,
#  'fuck': 485,
#  'wonder': 486,
#  'walk': 487,
#  'train': 488,
#  'moon': 489,
#  'wake': 490,
#  'ask': 491,
#  'band': 492,
#  'pool': 493,
#  'holiday': 494,
#  'driving': 495,
#  'la': 496,
#  'ppl': 497,
#  'remember': 498,
#  'crap': 499,
#  'enjoying': 500,
#  'mac': 501,
#  'died': 502,
#  'sent': 503,
#  'line': 504,
#  'pay': 505,
#  'seems': 506,
#  'math': 507,
#  'fast': 508,
#  'final': 509,
#  'seeing': 510,
#  'reason': 511,
#  'saying': 512,
#  '1st': 513,
#  'fail': 514,
#  'second': 515,
#  'youll': 516,
#  'page': 517,
#  'drive': 518,
#  '12': 519,
#  'perfect': 520,
#  'message': 521,
#  'twilight': 522,
#  'turn': 523,
#  'red': 524,
#  '100': 525,
#  'three': 526,
#  'cake': 527,
#  'internet': 528,
#  'pain': 529,
#  'high': 530,
#  'used': 531,
#  'yea': 532,
#  'sat': 533,
#  'fucking': 534,
#  'wouldnt': 535,
#  'finger': 536,
#  'sitting': 537,
#  'starting': 538,
#  'congrats': 539,
#  'air': 540,
#  'happened': 541,
#  'unfortunately': 542,
#  'jonas': 543,
#  'nite': 544,
#  'jealous': 545,
#  'pick': 546,
#  'anyway': 547,
#  'agree': 548,
#  'uk': 549,
#  'xd': 550,
#  'via': 551,
#  'june': 552,
#  'site': 553,
#  'town': 554,
#  'knew': 555,
#  'dance': 556,
#  'followfriday': 557,
#  'cut': 558,
#  'huge': 559,
#  'dress': 560,
#  'arent': 561,
#  'da': 562,
#  'supposed': 563,
#  'hang': 564,
#  'youve': 565,
#  'window': 566,
#  'apparently': 567,
#  'chocolate': 568,
#  'box': 569,
#  'ahh': 570,
#  'body': 571,
#  'episode': 572,
#  'btw': 573,
#  'seem': 574,
#  'studying': 575,
#  'fall': 576,
#  'sometimes': 577,
#  'seriously': 578,
#  'loved': 579,
#  'smile': 580,
#  'exciting': 581,
#  'mum': 582,
#  'dear': 583,
#  'moving': 584,
#  'bye': 585,
#  'point': 586,
#  'green': 587,
#  'moment': 588,
#  'worth': 589,
#  'officially': 590,
#  'top': 591,
#  'hoping': 592,
#  'kill': 593,
#  'catch': 594,
#  'son': 595,
#  'mr': 596,
#  'flight': 597,
#  'nap': 598,
#  'behind': 599,
#  'youtube': 600,
#  'course': 601,
#  'black': 602,
#  'happen': 603,
#  'deal': 604,
#  'homework': 605,
#  'guitar': 606,
#  'store': 607,
#  'throat': 608,
#  'fine': 609,
#  'â': 610,
#  'leg': 611,
#  'degree': 612,
#  'walking': 613,
#  'gave': 614,
#  'running': 615,
#  '20': 616,
#  'bring': 617,
#  'chance': 618,
#  'yup': 619,
#  'age': 620,
#  'usually': 621,
#  'park': 622,
#  'happens': 623,
#  'scary': 624,
#  'water': 625,
#  'die': 626,
#  'website': 627,
#  'favorite': 628,
#  'scared': 629,
#  'heard': 630,
#  'hows': 631,
#  'forget': 632,
#  'loving': 633,
#  'date': 634,
#  'mind': 635,
#  'wedding': 636,
#  'load': 637,
#  'small': 638,
#  'matter': 639,
#  'fair': 640,
#  'camera': 641,
#  'pas': 642,
#  'bitch': 643,
#  'taken': 644,
#  'waking': 645,
#  'different': 646,
#  'hmm': 647,
#  'ohh': 648,
#  'inside': 649,
#  'fb': 650,
#  'yall': 651,
#  'door': 652,
#  'flu': 653,
#  'gt': 654,
#  'mtv': 655,
#  'french': 656,
#  'min': 657,
#  'worse': 658,
#  'ahhh': 659,
#  'ipod': 660,
#  'share': 661,
#  'lose': 662,
#  'clean': 663,
#  'broken': 664,
#  'special': 665,
#  'babe': 666,
#  'cream': 667,
#  'ow': 668,
#  'bus': 669,
#  'past': 670,
#  'hospital': 671,
#  'killing': 672,
#  'etc': 673,
#  'decided': 674,
#  'cheer': 675,
#  'cd': 676,
#  'rip': 677,
#  'doctor': 678,
#  'wear': 679,
#  'number': 680,
#  'answer': 681,
#  'couple': 682,
#  'gosh': 683,
#  'gym': 684,
#  'hangover': 685,
#  'power': 686,
#  'realized': 687,
#  'screen': 688,
#  'touch': 689,
#  'team': 690,
#  'staying': 691,
#  'plus': 692,
#  'along': 693,
#  'clothes': 694,
#  'blue': 695,
#  'pizza': 696,
#  'giving': 697,
#  'proud': 698,
#  'account': 699,
#  'voice': 700,
#  'drunk': 701,
#  'bc': 702,
#  'single': 703,
#  'spend': 704,
#  'shame': 705,
#  '30': 706,
#  'spent': 707,
#  'dying': 708,
#  'save': 709,
#  'road': 710,
#  'learn': 711,
#  'goodbye': 712,
#  'warm': 713,
#  'bike': 714,
#  'shower': 715,
#  'weird': 716,
#  'tummy': 717,
#  'shop': 718,
#  'ahead': 719,
#  'near': 720,
#  'liked': 721,
#  'comment': 722,
#  'daddy': 723,
#  'graduation': 724,
#  'understand': 725,
#  'vacation': 726,
#  'parent': 727,
#  'college': 728,
#  'swear': 729,
#  '15': 730,
#  'battery': 731,
#  'group': 732,
#  'support': 733,
#  'cleaning': 734,
#  'absolutely': 735,
#  'upset': 736,
#  'double': 737,
#  'k': 738,
#  'slow': 739,
#  'roll': 740,
#  'album': 741,
#  'dark': 742,
#  'yr': 743,
#  'film': 744,
#  'shirt': 745,
#  'note': 746,
#  'nose': 747,
#  'random': 748,
#  'question': 749,
#  'lazy': 750,
#  'fell': 751,
#  'bro': 752,
#  'living': 753,
#  'earlier': 754,
#  'met': 755,
#  'cup': 756,
#  'sale': 757,
#  'lesson': 758,
#  'wishing': 759,
#  'worked': 760,
#  'normal': 761,
#  'felt': 762,
#  'traffic': 763,
#  'bet': 764,
#  'shot': 765,
#  'worst': 766,
#  'nope': 767,
#  'chillin': 768,
#  'pc': 769,
#  'issue': 770,
#  'hun': 771,
#  'choice': 772,
#  '9': 773,
#  'tom': 774,
#  'woot': 775,
#  'father': 776,
#  'dm': 777,
#  'safe': 778,
#  'airport': 779,
#  'google': 780,
#  'serious': 781,
#  'series': 782,
#  'student': 783,
#  'star': 784,
#  'result': 785,
#  'listen': 786,
#  'wat': 787,
#  'looked': 788,
#  'chat': 789,
#  'kick': 790,
#  'enjoyed': 791,
#  'tear': 792,
#  'fit': 793,
#  'si': 794,
#  'headed': 795,
#  'shoot': 796,
#  'huh': 797,
#  'brain': 798,
#  'beer': 799,
#  'alot': 800,
#  'diversity': 801,
#  'drinking': 802,
#  'upload': 803,
#  'hahah': 804,
#  'relaxing': 805,
#  'london': 806,
#  'co': 807,
#  '2day': 808,
#  'miley': 809,
#  'easy': 810,
#  'holy': 811,
#  'cried': 812,
#  'join': 813,
#  'profile': 814,
#  'future': 815,
#  'horrible': 816,
#  'american': 817,
#  'death': 818,
#  'everybody': 819,
#  'exactly': 820,
#  'mile': 821,
#  'sunshine': 822,
#  'honey': 823,
#  'fantastic': 824,
#  'pro': 825,
#  'especially': 826,
#  'mood': 827,
#  'company': 828,
#  'tan': 829,
#  'favourite': 830,
#  'suppose': 831,
#  'figure': 832,
#  'foot': 833,
#  'throw': 834,
#  'egg': 835,
#  'lately': 836,
#  'aint': 837,
#  'camp': 838,
#  'bummer': 839,
#  'others': 840,
#  'tuesday': 841,
#  'yo': 842,
#  'event': 843,
#  'radio': 844,
#  'hold': 845,
#  'project': 846,
#  'history': 847,
#  'fix': 848,
#  'turned': 849,
#  'longer': 850,
#  'sold': 851,
#  'sweetie': 852,
#  'wife': 853,
#  'fly': 854,
#  'spot': 855,
#  'worried': 856,
#  'jack': 857,
#  'myspace': 858,
#  'dropped': 859,
#  'boyfriend': 860,
#  'none': 861,
#  'peace': 862,
#  'imagine': 863,
#  'miami': 864,
#  'bunch': 865,
#  'bless': 866,
#  'piece': 867,
#  'meant': 868,
#  'except': 869,
#  'hasnt': 870,
#  'nobody': 871,
#  'track': 872,
#  'plane': 873,
#  'ran': 874,
#  'entire': 875,
#  'ball': 876,
#  'dat': 877,
#  'chicago': 878,
#  'copy': 879,
#  'goal': 880,
#  'fucked': 881,
#  'allowed': 882,
#  'mention': 883,
#  'jus': 884,
#  'quiet': 885,
#  'fire': 886,
#  'bag': 887,
#  'record': 888,
#  'feed': 889,
#  'passed': 890,
#  '14': 891,
#  'anyways': 892,
#  'shoe': 893,
#  'state': 894,
#  'street': 895,
#  'calling': 896,
#  'coz': 897,
#  'front': 898,
#  'hill': 899,
#  'laughing': 900,
#  'side': 901,
#  'simple': 902,
#  '4th': 903,
#  'dang': 904,
#  'garden': 905,
#  'tix': 906,
#  'laugh': 907,
#  'fact': 908,
#  'sign': 909,
#  'sam': 910,
#  'forever': 911,
#  'download': 912,
#  'dunno': 913,
#  'cousin': 914,
#  'watchin': 915,
#  'jon': 916,
#  'butt': 917,
#  'failed': 918,
#  'wit': 919,
#  'become': 920,
#  'afraid': 921,
#  'epic': 922,
#  'showing': 923,
#  'slept': 924,
#  'killed': 925,
#  'sort': 926,
#  'arm': 927,
#  'often': 928,
#  'lyric': 929,
#  'fever': 930,
#  'beat': 931,
#  'fat': 932,
#  'memory': 933,
#  'david': 934,
#  'pink': 935,
#  'grade': 936,
#  'wine': 937,
#  'c': 938,
#  'positive': 939,
#  'fixed': 940,
#  '50': 941,
#  'background': 942,
#  'blood': 943,
#  'king': 944,
#  'bar': 945,
#  'everywhere': 946,
#  'quot': 947,
#  'gunna': 948,
#  'sadly': 949,
#  'cook': 950,
#  'picked': 951,
#  'order': 952,
#  'idk': 953,
#  'quick': 954,
#  'bird': 955,
#  'fried': 956,
#  'mark': 957,
#  'wondering': 958,
#  'blackberry': 959,
#  'weight': 960,
#  'ooh': 961,
#  'cell': 962,
#  'ouch': 963,
#  'wii': 964,
#  'kiss': 965,
#  'blocked': 966,
#  'chapter': 967,
#  'completely': 968,
#  'confused': 969,
#  'stomach': 970,
#  'england': 971,
#  'seat': 972,
#  'chris': 973,
#  'country': 974,
#  '2nd': 975,
#  'xoxo': 976,
#  'oops': 977,
#  'annoying': 978,
#  'lakers': 979,
#  'bill': 980,
#  'middle': 981,
#  'tweeted': 982,
#  'indeed': 983,
#  'played': 984,
#  'fresh': 985,
#  'expect': 986,
#  'station': 987,
#  'waste': 988,
#  'gutted': 989,
#  'brought': 990,
#  'although': 991,
#  'interview': 992,
#  'ugly': 993,
#  'gettin': 994,
#  'studio': 995,
#  'difficult': 996,
#  'price': 997,
#  'packed': 998,
#  'sing': 999,
#  ...}

# %% [markdown]
# 2. Creating Embedding matrix

# %%
embedding_matrix = np.zeros((len(word2vec.wv.key_to_index), embedding_length))

embedding_matrix.shape
# Out:
# (13914, 200)

# %%
for token, idx in word_index.items():
    if word2vec.wv.__contains__(token):
        embedding_matrix[idx] = word2vec.wv[token]

print("Embedding matrix :")
print(embedding_matrix)
# Out:
# Embedding matrix :
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [ 8.77706427e-03 -6.50832153e-05  5.43886796e-03 ... -1.20586539e-02
#   -1.25540624e-04 -7.39952503e-03]
#  ...
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]]

# %% [markdown]
# #### Model Creation

# %%
model = Sequential()

# input layer
model.add(Embedding(input_dim = len(word2vec.wv.key_to_index),
                    output_dim=embedding_length,
                    weights=[embedding_matrix], 
                    input_length=max_len, 
                    trainable = True))
model.add(Bidirectional(LSTM(units=100, return_sequences=True, dropout=0.2)))
model.add(Bidirectional(LSTM(units=50, return_sequences=True, dropout=0.2)))
model.add(GlobalMaxPooling1D())

# hidden layer
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.2))

# output layer
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer=Adam(learning_rate=0.0001), loss = 'binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_8 (Embedding)     (None, 27, 200)           2782800
#
#  bidirectional_10 (Bidirect  (None, 27, 200)           240800
#  ional)
#
#  bidirectional_11 (Bidirect  (None, 27, 100)           100400
#  ional)
#
#  global_max_pooling1d_7 (Gl  (None, 100)               0
#  obalMaxPooling1D)
#
#  dense_23 (Dense)            (None, 16)                1616
#
#  dropout_15 (Dropout)        (None, 16)                0
#
#  dense_24 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 3125633 (11.92 MB)
# Trainable params: 3125633 (11.92 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
early_stopping = EarlyStopping( monitor='val_accuracy', restore_best_weights=True, patience=3)

# %%
model.fit(x_train, y_train, epochs=e_pochs, batch_size=batch_size, validation_data=(x_val, y_val), callbacks=[early_stopping])
# Out:
# Epoch 1/10
# 125/125 [==============================] - 17s 89ms/step - loss: 0.6922 - accuracy: 0.5175 - val_loss: 0.6907 - val_accuracy: 0.5311
# Epoch 2/10
# 125/125 [==============================] - 10s 79ms/step - loss: 0.6889 - accuracy: 0.5430 - val_loss: 0.6876 - val_accuracy: 0.5562
# Epoch 3/10
# 125/125 [==============================] - 10s 79ms/step - loss: 0.6800 - accuracy: 0.5716 - val_loss: 0.6721 - val_accuracy: 0.5622
# Epoch 4/10
# 125/125 [==============================] - 10s 79ms/step - loss: 0.5866 - accuracy: 0.7075 - val_loss: 0.5799 - val_accuracy: 0.7169
# Epoch 5/10
# 125/125 [==============================] - 10s 80ms/step - loss: 0.4600 - accuracy: 0.8012 - val_loss: 0.5650 - val_accuracy: 0.7209
# Epoch 6/10
# 125/125 [==============================] - 10s 79ms/step - loss: 0.3877 - accuracy: 0.8399 - val_loss: 0.6097 - val_accuracy: 0.6928
# Epoch 7/10
# 125/125 [==============================] - 10s 81ms/step - loss: 0.3095 - accuracy: 0.8799 - val_loss: 0.6329 - val_accuracy: 0.7179
# Epoch 8/10
# 125/125 [==============================] - 10s 83ms/step - loss: 0.2543 - accuracy: 0.9068 - val_loss: 0.6816 - val_accuracy: 0.7139

# %%
print("Accuracy :",model.evaluate(x_test, y_test)[1]*100,"%")
# Out:
# 32/32 [==============================] - 0s 10ms/step - loss: 0.5463 - accuracy: 0.7347
# Accuracy : 73.46733808517456 %
